# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GATConv, global_mean_pool
from torch_geometric.loader import DataLoader  
from torch_geometric.nn import global_mean_pool, global_add_pool  
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
# Out:
# /Users/jifengwang/anaconda3/lib/python3.11/site-packages/torch_geometric/typing.py:54: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: dlopen(/Users/jifengwang/anaconda3/lib/python3.11/site-packages/libpyg.so, 0x0006): Library not loaded: /Library/Frameworks/Python.framework/Versions/3.11/Python
#   Referenced from: <75FFC412-93B5-322B-8E6D-268DA3498CF4> /Users/jifengwang/anaconda3/lib/python3.11/site-packages/libpyg.so
#   Reason: tried: '/Library/Frameworks/Python.framework/Versions/3.11/Python' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Library/Frameworks/Python.framework/Versions/3.11/Python' (no such file), '/Library/Frameworks/Python.framework/Versions/3.11/Python' (no such file)
#   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# /Users/jifengwang/anaconda3/lib/python3.11/site-packages/torch_geometric/typing.py:110: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: dlopen(/Users/jifengwang/anaconda3/lib/python3.11/site-packages/libpyg.so, 0x0006): Library not loaded: /Library/Frameworks/Python.framework/Versions/3.11/Python
#   Referenced from: <75FFC412-93B5-322B-8E6D-268DA3498CF4> /Users/jifengwang/anaconda3/lib/python3.11/site-packages/libpyg.so
#   Reason: tried: '/Library/Frameworks/Python.framework/Versions/3.11/Python' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Library/Frameworks/Python.framework/Versions/3.11/Python' (no such file), '/Library/Frameworks/Python.framework/Versions/3.11/Python' (no such file)
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "

# %%
plt.style.use("style.mplstyle")

# %%
# Fix random seed
def set_seed(seed):
    import random
    random.seed(seed)  # Fix Python's random seed
    np.random.seed(seed)  # Fix NumPy's random seed
    torch.manual_seed(seed)  # Fix PyTorch's random seed
    torch.cuda.manual_seed(seed)  # Fix random seed on GPU
    torch.backends.cudnn.deterministic = True  # Ensure CuDNN determinism
    torch.backends.cudnn.benchmark = False  # Disable non-deterministic algorithm optimization

# Call at the beginning of the function
set_seed(42)  # 42 is the seed value, can be replaced with other values

# %%
import torch
# Load dataset
def load_data_list(file_path):
    """
    Load a data list from a specified file path.

    Parameters:
    file_path (str): Path to the data list file.

    Returns:
    list: Loaded data list.
    """
    return torch.load(file_path)

############## Anion ##############
anion_load_file_path = 'dataset/anion_data_list.pt' # Complete dataset
anion_load_train_dataset_path = 'dataset/train_anion_data_list.pt' # Training set
anion_load_val_dataset_path = 'dataset/val_anion_data_list.pt' # Validation set
#anion_load_test_dataset_path = 'dataset/test_anion_data_list.pt' # Test set

# Load datasets
anion_loaded_data_list = load_data_list(anion_load_file_path)
anion_loaded_train_data_list = load_data_list(anion_load_train_dataset_path)
anion_loaded_val_data_list = load_data_list(anion_load_val_dataset_path)
#anion_loaded_test_data_list = load_data_list(anion_load_test_dataset_path)

# Print information about loaded datasets
print(f"Size of the loaded data list: {len(anion_loaded_data_list)}")
print(f"Size of the loaded training data list: {len(anion_loaded_train_data_list)}")
print(f"Size of the loaded validation data list: {len(anion_loaded_val_data_list)}")
#print(f"Size of the loaded test data list: {len(anion_loaded_test_data_list)}")

# Load training, validation, and test datasets
anion_train_loader = DataLoader(anion_loaded_train_data_list, batch_size=128, shuffle=True)  
anion_val_loader = DataLoader(anion_loaded_val_data_list, batch_size=128, shuffle=False)  
#anion_test_loader = DataLoader(anion_loaded_test_data_list, batch_size=128, shuffle=False)  


############## Cation ##############
cation_load_file_path = 'dataset/cation_data_list.pt' # Complete dataset
cation_load_train_dataset_path = 'dataset/train_cation_data_list.pt' # Training set
cation_load_val_dataset_path = 'dataset/val_cation_data_list.pt' # Validation set
#cation_load_test_dataset_path = 'dataset/test_cation_data_list.pt' # Test set

# Load datasets
cation_loaded_data_list = load_data_list(cation_load_file_path)
cation_loaded_train_data_list = load_data_list(cation_load_train_dataset_path)
cation_loaded_val_data_list = load_data_list(cation_load_val_dataset_path)
#cation_loaded_test_data_list = load_data_list(cation_load_test_dataset_path)

# Print information about loaded datasets
print(f"Size of the loaded data list: {len(cation_loaded_data_list)}")
print(f"Size of the loaded training data list: {len(cation_loaded_train_data_list)}")
print(f"Size of the loaded validation data list: {len(cation_loaded_val_data_list)}")
#print(f"Size of the loaded test data list: {len(cation_loaded_test_data_list)}")

# Load training, validation, and test datasets
cation_train_loader = DataLoader(cation_loaded_train_data_list, batch_size=128, shuffle=True)  
cation_val_loader = DataLoader(cation_loaded_val_data_list, batch_size=128, shuffle=False)  
#cation_test_loader = DataLoader(cation_loaded_test_data_list, batch_size=128, shuffle=False)
# Out:
# Size of the loaded data list: 2220
# Size of the loaded training data list: 1776
# Size of the loaded validation data list: 444
# Size of the loaded data list: 3774
# Size of the loaded training data list: 3019
# Size of the loaded validation data list: 755

# %%
class GAT(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels=1, num_heads=4):
        """
        Initialization function to define the model's layer structure.

        Parameters:
        - in_channels (int): Dimension of input node features, i.e., the length of each node feature vector.
        - hidden_channels (int): Dimension of hidden layer features.
        - out_channels (int): Dimension of output features.
        - num_heads (int): Number of heads in multi-head attention.

        Example:
        If the input node feature dimension is 11, hidden layer dimension is 8, output dimension is 1, and the number of attention heads is 4:
        model = GAT(in_channels=11, hidden_channels=8, out_channels=1, num_heads=4)
        """
        super(GAT, self).__init__()
        # Define the first graph attention convolution layer
        self.conv1 = GATConv(in_channels, hidden_channels, heads=num_heads, concat=True)
        # Define the second graph attention convolution layer
        self.conv2 = GATConv(hidden_channels * num_heads, hidden_channels, heads=num_heads, concat=True)
        # Define the third graph attention convolution layer
        self.conv3 = GATConv(hidden_channels * num_heads, hidden_channels, heads=1, concat=False)
        # Define the fully connected layer to map features to the final output dimension
        self.lin = torch.nn.Linear(hidden_channels, out_channels)

    def forward(self, data):
        """
        Forward propagation function defining how data passes through the model.

        Parameters:
        - data: Batch object containing graph data with the following attributes:
            - x (Tensor): Node feature matrix, shape [num_nodes, in_channels]
            - edge_index (Tensor): Edge index matrix, shape [2, num_edges]
            - batch (Tensor): Index of the graph each node belongs to, shape [num_nodes]

        Returns:
        - out (Tensor): Model prediction output, shape [batch_size, out_channels]
        """
        x = data.x  # Node feature matrix, shape [num_nodes, in_channels]
        edge_index = data.edge_index  # Edge index matrix, shape [2, num_edges]
        batch = data.batch  # Graph index of each node, shape [num_nodes]

        # First graph attention convolution layer
        x = self.conv1(x, edge_index)
        # x shape updated to [num_nodes, hidden_channels * num_heads]
        x = F.elu(x)  # Activation function

        # Second graph attention convolution layer
        x = self.conv2(x, edge_index)
        # x shape updated to [num_nodes, hidden_channels * num_heads]
        x = F.elu(x)

        # Third graph attention convolution layer
        x = self.conv3(x, edge_index)
        # x shape updated to [num_nodes, hidden_channels]
        x = F.elu(x)

        # Global mean pooling to aggregate node features into graph features
        x = global_mean_pool(x, batch)
        # x shape updated to [batch_size, hidden_channels]

        # Dropout layer to prevent overfitting
        x = F.dropout(x, p=0.5, training=self.training)
        # x shape remains [batch_size, hidden_channels]

        # Fully connected layer to output the final prediction result
        out = self.lin(x)
        # out shape is [batch_size, out_channels]

        return out

# %%
# Calculate the number of model parameters
def count_parameters(model):
    """
    Calculate the total number of parameters in the model.
    Parameters:
        model: PyTorch model
    Returns:
        total_params: Total number of parameters in the model
    """
    total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total_params

# %%
import torch
import torch.nn.functional as F
import numpy as np
import math

# Set device to GPU (if available), otherwise use CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def training(index, loader, model, loss_fn, optimizer):
    """
    Training function for one epoch.

    Parameters:
    - loader: DataLoader object, training data loader
    - model: Model to be trained
    - loss_fn: Loss function
    - optimizer: Optimizer

    Returns:
    - average_loss: Average loss for the current epoch
    """
    model.train()  # Set model to training mode
    total_loss = 0  # Initialize total loss
    for data in loader:  # Iterate through each batch of data
        data = data.to(device)  # Move data to GPU
        optimizer.zero_grad()  # Clear gradients
        data.x = data.x.float()  # Convert node features to float
        out = model(data)  # Forward pass to calculate output
        loss = loss_fn(out, 27.2 * data.y[:, index].view(-1, 1))  # Use only the last column of y as the ground truth
        loss.backward()  # Backward pass to compute gradients
        optimizer.step()  # Update model parameters
        total_loss += loss.item()  # Accumulate loss
    average_loss = total_loss / len(loader)  # Compute average loss
    return average_loss  # Return average loss for the current epoch

def validation(index, loader, model, loss_fn):
    """
    Validation function to evaluate model performance on the validation set.

    Parameters:
    - loader: DataLoader object, validation data loader
    - model: Model to be evaluated
    - loss_fn: Loss function

    Returns:
    - average_loss: Average loss on the validation set
    """
    model.eval()  # Set model to evaluation mode
    total_loss = 0  # Initialize total loss
    with torch.no_grad():  # Disable gradient computation to save memory
        for data in loader:  # Iterate through each batch in the validation set
            data = data.to(device)  # Move data to GPU
            data.x = data.x.float()  # Convert node features to float
            out = model(data)  # Forward pass to calculate output
            loss = loss_fn(out, 27.2 * data.y[:, index].view(-1, 1))  # Use only the last column of y as the ground truth
            total_loss += loss.item()  # Accumulate loss
    average_loss = total_loss / len(loader)  # Compute average loss
    return average_loss  # Return average loss on the validation set

@torch.no_grad()  # Disable gradient computation to save memory
def testing(index, loader, model):
    """
    Testing function to evaluate model performance on the test set and obtain predictions.

    Parameters:
    - loader: DataLoader object, test data loader
    - model: Model to be evaluated

    Returns:
    - average_loss: Average loss on the test set
    - test_pred: Predicted values on the test set
    - test_true: True target values on the test set
    """
    loss_fn = torch.nn.MSELoss()  # Define mean squared error loss function
    total_loss = 0  # Initialize total loss
    test_pred = []  # List to store predicted values
    test_true = []  # List to store true values
    for data in loader:  # Iterate through each batch in the test set
        data = data.to(device)  # Move data to GPU
        data.x = data.x.float()  # Convert node features to float
        out = model(data)  # Forward pass to calculate output
        loss = loss_fn(out, 27.2 * data.y[:, index].view(-1, 1))  # Use only the last column of y as the ground truth
        total_loss += loss.item()  # Accumulate loss

        # Save predicted values and true targets for visualization
        test_pred.append(out.cpu().numpy())  # Move predictions to CPU and convert to numpy array
        test_true.append(data.y[:, index].cpu().numpy())  # Move true targets to CPU and convert to numpy array

    test_pred = np.concatenate(test_pred, axis=0)  # Concatenate predictions from all batches
    test_true = np.concatenate(test_true, axis=0)  # Concatenate true targets from all batches
    average_loss = total_loss / len(loader)  # Compute average loss
    return average_loss, test_pred, test_true  # Return test loss and predictions

def train_epochs(index, epochs, model, train_loader, val_loader, path):
    """
    Train for multiple epochs and validate after each epoch.

    Parameters:
    - epochs: Total number of epochs
    - model: Model to be trained
    - train_loader: DataLoader object, training data loader
    - val_loader: DataLoader object, validation data loader
    - path: Path to save the best model

    Returns:
    - train_losses: Array containing training loss for each epoch
    - val_losses: Array containing validation loss for each epoch
    - train_pred: Predicted values on the training set from the last epoch
    - train_true: True target values on the training set from the last epoch
    """
    optimizer = torch.optim.Adam(model.parameters(), lr=5e-4, weight_decay=5e-4)  # Define optimizer
    loss_fn = torch.nn.MSELoss()  # Define mean squared error loss function

    train_losses = np.zeros(epochs)  # Initialize array to store training loss for each epoch
    val_losses = np.zeros(epochs)  # Initialize array to store validation loss for each epoch
    best_loss = float('inf')  # Initialize best validation loss to infinity

    for epoch in range(epochs):  # Iterate through each epoch
        # Train for one epoch and get average loss
        train_loss = training(index, train_loader, model, loss_fn, optimizer)
        # Validate the current model and get average loss
        val_loss = validation(index, val_loader, model, loss_fn)
        # If the current validation loss is lower than the best loss, save the model
        if val_loss < best_loss:
            best_loss = val_loss
            torch.save(model.state_dict(), path)  # Save the current best model

        # Record losses
        train_losses[epoch] = train_loss
        val_losses[epoch] = val_loss

        # Print current training and validation loss every 2 epochs
        if epoch % 2 == 0:
            print(f"Epoch: {epoch}, Train loss: {train_loss:.4f}, Val loss: {val_loss:.4f}")

    # Get predictions and true targets on the training set for the last epoch
    train_pred = []
    train_true = []
    model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        for data in train_loader:
            data = data.to(device)  # Move data to GPU
            data.x = data.x.float()  # Convert node features to float
            out = model(data)
            train_pred.append(out.cpu().numpy())
            train_true.append(27.2 * data.y[:, index].cpu().numpy())  # Store only the last column of true targets
    train_pred = np.concatenate(train_pred, axis=0)
    train_true = np.concatenate(train_true, axis=0)

    # Get predictions and true targets on the validation set for the last epoch
    val_pred = []
    val_true = []
    with torch.no_grad():  # Disable gradient computation
        for data in val_loader:  # Iterate through the validation set
            data = data.to(device)
            data.x = data.x.float()
            out = model(data)  # Model prediction
            val_pred.append(out.cpu().numpy())  # Store predicted values
            val_true.append(27.2 * data.y[:, index].cpu().numpy())  # Store true targets (last column)
    val_pred = np.concatenate(val_pred, axis=0)  # Concatenate predictions from all batches
    val_true = np.concatenate(val_true, axis=0)  # Concatenate true targets from all batches
    
    # Compute MSE and MAE on the validation set
    mse = mean_squared_error(val_true, val_pred)
    mae = mean_absolute_error(val_true, val_pred)
    print(f"Validation MSE: {mse:.4f}, MAE: {mae:.4f}")
    
    return train_losses, val_losses, train_pred, train_true, val_pred, val_true, mse, mae  # Return losses and predictions

# %%
# Initialize GCN model with hidden layer dimension set to 256
model_anion = GAT(in_channels=5, hidden_channels=256).to(device) 
model_cation = GAT(in_channels=5, hidden_channels=256).to(device) 

print(f"Total number of parameters in the model: {count_parameters(model_anion)}")

# %%
# Train the GCN model with the number of epochs set to 100
epochs = 500

# The unit of Hartree is too small; convert it to eV by multiplying by 27.2

# Call the train_epochs function to train the model; for anions, train for HOMO
anion_gat_train_loss, anion_gat_val_loss, anion_gat_train_pred, anion_gat_train_true, anion_gat_val_pred, anion_gat_val_true, anion_gat_mse, anion_gat_mae = train_epochs(
    11, epochs, model_anion, anion_train_loader, anion_val_loader, "Anion_GAT_model_HOMO.pt"
)
# Out:
# Epoch: 0, Train loss: 1.9025, Val loss: 1.1308
# Epoch: 2, Train loss: 1.0108, Val loss: 0.7877
# Epoch: 4, Train loss: 0.9111, Val loss: 0.8226
# Epoch: 6, Train loss: 0.8459, Val loss: 0.6915
# Epoch: 8, Train loss: 0.8406, Val loss: 0.6879
# Epoch: 10, Train loss: 0.8431, Val loss: 0.6816
# Epoch: 12, Train loss: 0.8129, Val loss: 0.6812
# Epoch: 14, Train loss: 0.7958, Val loss: 0.6819
# Epoch: 16, Train loss: 0.8063, Val loss: 0.6643
# Epoch: 18, Train loss: 0.7951, Val loss: 0.6566
# Epoch: 20, Train loss: 0.8266, Val loss: 0.7559
# Epoch: 22, Train loss: 0.7544, Val loss: 0.6435
# Epoch: 24, Train loss: 0.7557, Val loss: 0.6341
# Epoch: 26, Train loss: 0.7670, Val loss: 0.6349
# Epoch: 28, Train loss: 0.7524, Val loss: 0.6667
# Epoch: 30, Train loss: 0.7323, Val loss: 0.6305
# Epoch: 32, Train loss: 0.7272, Val loss: 0.6152
# Epoch: 34, Train loss: 0.7233, Val loss: 0.6057
# Epoch: 36, Train loss: 0.7173, Val loss: 0.6286
# Epoch: 38, Train loss: 0.7013, Val loss: 0.6045
# Epoch: 40, Train loss: 0.6844, Val loss: 0.6071
# Epoch: 42, Train loss: 0.6825, Val loss: 0.5860
# Epoch: 44, Train loss: 0.6477, Val loss: 0.5631
# Epoch: 46, Train loss: 0.6727, Val loss: 0.5495
# Epoch: 48, Train loss: 0.6587, Val loss: 0.5522
# Epoch: 50, Train loss: 0.6761, Val loss: 0.5495
# Epoch: 52, Train loss: 0.6765, Val loss: 0.5720
# Epoch: 54, Train loss: 0.6472, Val loss: 0.5489
# Epoch: 56, Train loss: 0.6279, Val loss: 0.5284
# Epoch: 58, Train loss: 0.6337, Val loss: 0.5370
# Epoch: 60, Train loss: 0.6706, Val loss: 0.6124
# Epoch: 62, Train loss: 0.6346, Val loss: 0.5547
# Epoch: 64, Train loss: 0.6057, Val loss: 0.5238
# Epoch: 66, Train loss: 0.6216, Val loss: 0.5596
# Epoch: 68, Train loss: 0.6094, Val loss: 0.5385
# Epoch: 70, Train loss: 0.6227, Val loss: 0.5856
# Epoch: 72, Train loss: 0.6171, Val loss: 0.5266
# Epoch: 74, Train loss: 0.5930, Val loss: 0.5480
# Epoch: 76, Train loss: 0.5908, Val loss: 0.5114
# Epoch: 78, Train loss: 0.6279, Val loss: 0.5196
# Epoch: 80, Train loss: 0.6235, Val loss: 0.5610
# Epoch: 82, Train loss: 0.5968, Val loss: 0.4999
# Epoch: 84, Train loss: 0.5648, Val loss: 0.4789
# Epoch: 86, Train loss: 0.5643, Val loss: 0.5188
# Epoch: 88, Train loss: 0.5980, Val loss: 0.4836
# Epoch: 90, Train loss: 0.5741, Val loss: 0.4818
# Epoch: 92, Train loss: 0.5676, Val loss: 0.4490
# Epoch: 94, Train loss: 0.5634, Val loss: 0.5286
# Epoch: 96, Train loss: 0.5759, Val loss: 0.4603
# Epoch: 98, Train loss: 0.5229, Val loss: 0.4634
# Epoch: 100, Train loss: 0.5092, Val loss: 0.4283
# Epoch: 102, Train loss: 0.5064, Val loss: 0.4259
# Epoch: 104, Train loss: 0.5006, Val loss: 0.4558
# Epoch: 106, Train loss: 0.4632, Val loss: 0.3995
# Epoch: 108, Train loss: 0.4590, Val loss: 0.3736
# Epoch: 110, Train loss: 0.4817, Val loss: 0.4193
# Epoch: 112, Train loss: 0.4885, Val loss: 0.4872
# Epoch: 114, Train loss: 0.4943, Val loss: 0.4027
# Epoch: 116, Train loss: 0.4268, Val loss: 0.3582
# Epoch: 118, Train loss: 0.4209, Val loss: 0.3633
# Epoch: 120, Train loss: 0.4204, Val loss: 0.4301
# Epoch: 122, Train loss: 0.4144, Val loss: 0.3500
# Epoch: 124, Train loss: 0.4284, Val loss: 0.3447
# Epoch: 126, Train loss: 0.4262, Val loss: 0.3559
# Epoch: 128, Train loss: 0.4200, Val loss: 0.3432
# Epoch: 130, Train loss: 0.4105, Val loss: 0.3517
# Epoch: 132, Train loss: 0.4528, Val loss: 0.4154
# Epoch: 134, Train loss: 0.3991, Val loss: 0.3402
# Epoch: 136, Train loss: 0.4188, Val loss: 0.4135
# Epoch: 138, Train loss: 0.3942, Val loss: 0.3853
# Epoch: 140, Train loss: 0.3825, Val loss: 0.3444
# Epoch: 142, Train loss: 0.3959, Val loss: 0.3331
# Epoch: 144, Train loss: 0.3754, Val loss: 0.3361
# Epoch: 146, Train loss: 0.3914, Val loss: 0.3299
# Epoch: 148, Train loss: 0.3889, Val loss: 0.3530
# Epoch: 150, Train loss: 0.4003, Val loss: 0.3300
# Epoch: 152, Train loss: 0.3835, Val loss: 0.3428
# Epoch: 154, Train loss: 0.3869, Val loss: 0.3740
# Epoch: 156, Train loss: 0.3863, Val loss: 0.3400
# Epoch: 158, Train loss: 0.3719, Val loss: 0.3373
# Epoch: 160, Train loss: 0.3744, Val loss: 0.3417
# Epoch: 162, Train loss: 0.3864, Val loss: 0.3566
# Epoch: 164, Train loss: 0.3760, Val loss: 0.3306
# Epoch: 166, Train loss: 0.3806, Val loss: 0.3267
# Epoch: 168, Train loss: 0.3632, Val loss: 0.3285
# Epoch: 170, Train loss: 0.3538, Val loss: 0.3201
# Epoch: 172, Train loss: 0.3726, Val loss: 0.3464
# Epoch: 174, Train loss: 0.3804, Val loss: 0.3300
# Epoch: 176, Train loss: 0.3582, Val loss: 0.3208
# Epoch: 178, Train loss: 0.3544, Val loss: 0.3394
# Epoch: 180, Train loss: 0.3660, Val loss: 0.3721
# Epoch: 182, Train loss: 0.3633, Val loss: 0.3222
# Epoch: 184, Train loss: 0.3781, Val loss: 0.3100
# Epoch: 186, Train loss: 0.3508, Val loss: 0.3078
# Epoch: 188, Train loss: 0.3621, Val loss: 0.3189
# Epoch: 190, Train loss: 0.3583, Val loss: 0.3266
# Epoch: 192, Train loss: 0.3551, Val loss: 0.3042
# Epoch: 194, Train loss: 0.3474, Val loss: 0.3252
# Epoch: 196, Train loss: 0.3620, Val loss: 0.3158
# Epoch: 198, Train loss: 0.3504, Val loss: 0.3057
# Epoch: 200, Train loss: 0.3371, Val loss: 0.3062
# Epoch: 202, Train loss: 0.3295, Val loss: 0.3084
# Epoch: 204, Train loss: 0.3514, Val loss: 0.3095
# Epoch: 206, Train loss: 0.3378, Val loss: 0.3040
# Epoch: 208, Train loss: 0.3439, Val loss: 0.3119
# Epoch: 210, Train loss: 0.3293, Val loss: 0.3712
# Epoch: 212, Train loss: 0.3248, Val loss: 0.2896
# Epoch: 214, Train loss: 0.3220, Val loss: 0.2957
# Epoch: 216, Train loss: 0.3362, Val loss: 0.3189
# Epoch: 218, Train loss: 0.3331, Val loss: 0.2840
# Epoch: 220, Train loss: 0.3042, Val loss: 0.2820
# Epoch: 222, Train loss: 0.3565, Val loss: 0.2995
# Epoch: 224, Train loss: 0.2855, Val loss: 0.2619
# Epoch: 226, Train loss: 0.3111, Val loss: 0.2961
# Epoch: 228, Train loss: 0.3013, Val loss: 0.2797
# Epoch: 230, Train loss: 0.2975, Val loss: 0.2745
# Epoch: 232, Train loss: 0.2791, Val loss: 0.2522
# Epoch: 234, Train loss: 0.2873, Val loss: 0.2662
# Epoch: 236, Train loss: 0.2810, Val loss: 0.2699
# Epoch: 238, Train loss: 0.3134, Val loss: 0.2486
# Epoch: 240, Train loss: 0.2718, Val loss: 0.2673
# Epoch: 242, Train loss: 0.2649, Val loss: 0.2636
# Epoch: 244, Train loss: 0.2812, Val loss: 0.2677
# Epoch: 246, Train loss: 0.2675, Val loss: 0.2445
# Epoch: 248, Train loss: 0.2633, Val loss: 0.2741
# Epoch: 250, Train loss: 0.2553, Val loss: 0.2475
# Epoch: 252, Train loss: 0.2514, Val loss: 0.2369
# Epoch: 254, Train loss: 0.2477, Val loss: 0.2448
# Epoch: 256, Train loss: 0.2532, Val loss: 0.2566
# Epoch: 258, Train loss: 0.2367, Val loss: 0.2500
# Epoch: 260, Train loss: 0.2366, Val loss: 0.2274
# Epoch: 262, Train loss: 0.2493, Val loss: 0.2244
# Epoch: 264, Train loss: 0.2518, Val loss: 0.2366
# Epoch: 266, Train loss: 0.2402, Val loss: 0.2196
# Epoch: 268, Train loss: 0.2479, Val loss: 0.2369
# Epoch: 270, Train loss: 0.2410, Val loss: 0.2289
# Epoch: 272, Train loss: 0.2335, Val loss: 0.2474
# Epoch: 274, Train loss: 0.2359, Val loss: 0.2192
# Epoch: 276, Train loss: 0.2404, Val loss: 0.2309
# Epoch: 278, Train loss: 0.2327, Val loss: 0.2263
# Epoch: 280, Train loss: 0.2437, Val loss: 0.2062
# Epoch: 282, Train loss: 0.2601, Val loss: 0.2792
# Epoch: 284, Train loss: 0.2284, Val loss: 0.2300
# Epoch: 286, Train loss: 0.2451, Val loss: 0.2319
# Epoch: 288, Train loss: 0.2391, Val loss: 0.2241
# Epoch: 290, Train loss: 0.2227, Val loss: 0.2143
# Epoch: 292, Train loss: 0.2246, Val loss: 0.2086
# Epoch: 294, Train loss: 0.2265, Val loss: 0.2203
# Epoch: 296, Train loss: 0.2262, Val loss: 0.1984
# Epoch: 298, Train loss: 0.2128, Val loss: 0.2138
# Epoch: 300, Train loss: 0.2286, Val loss: 0.2152
# Epoch: 302, Train loss: 0.2241, Val loss: 0.2078
# Epoch: 304, Train loss: 0.2305, Val loss: 0.2070
# Epoch: 306, Train loss: 0.2353, Val loss: 0.2233
# Epoch: 308, Train loss: 0.2377, Val loss: 0.2029
# Epoch: 310, Train loss: 0.2179, Val loss: 0.2006
# Epoch: 312, Train loss: 0.2139, Val loss: 0.2157
# Epoch: 314, Train loss: 0.2272, Val loss: 0.2214
# Epoch: 316, Train loss: 0.2564, Val loss: 0.2329
# Epoch: 318, Train loss: 0.2652, Val loss: 0.2909
# Epoch: 320, Train loss: 0.2442, Val loss: 0.2190
# Epoch: 322, Train loss: 0.2390, Val loss: 0.2791
# Epoch: 324, Train loss: 0.2210, Val loss: 0.2092
# Epoch: 326, Train loss: 0.2140, Val loss: 0.2081
# Epoch: 328, Train loss: 0.2149, Val loss: 0.1998
# Epoch: 330, Train loss: 0.2132, Val loss: 0.2084
# Epoch: 332, Train loss: 0.2508, Val loss: 0.2101
# Epoch: 334, Train loss: 0.2390, Val loss: 0.2492
# Epoch: 336, Train loss: 0.2103, Val loss: 0.2072
# Epoch: 338, Train loss: 0.2181, Val loss: 0.2038
# Epoch: 340, Train loss: 0.2142, Val loss: 0.2253
# Epoch: 342, Train loss: 0.2225, Val loss: 0.2033
# Epoch: 344, Train loss: 0.2082, Val loss: 0.2053
# Epoch: 346, Train loss: 0.2267, Val loss: 0.1964
# Epoch: 348, Train loss: 0.2265, Val loss: 0.2259
# Epoch: 350, Train loss: 0.2533, Val loss: 0.3082
# Epoch: 352, Train loss: 0.2197, Val loss: 0.2145
# Epoch: 354, Train loss: 0.2118, Val loss: 0.1999
# Epoch: 356, Train loss: 0.2051, Val loss: 0.1969
# Epoch: 358, Train loss: 0.2019, Val loss: 0.2187
# Epoch: 360, Train loss: 0.2237, Val loss: 0.2166
# Epoch: 362, Train loss: 0.2208, Val loss: 0.2182
# Epoch: 364, Train loss: 0.2042, Val loss: 0.2185
# Epoch: 366, Train loss: 0.2328, Val loss: 0.1927
# Epoch: 368, Train loss: 0.2129, Val loss: 0.1979
# Epoch: 370, Train loss: 0.2142, Val loss: 0.1990
# Epoch: 372, Train loss: 0.2088, Val loss: 0.2547
# Epoch: 374, Train loss: 0.2187, Val loss: 0.2154
# Epoch: 376, Train loss: 0.2050, Val loss: 0.1996
# Epoch: 378, Train loss: 0.2132, Val loss: 0.2007
# Epoch: 380, Train loss: 0.2285, Val loss: 0.2279
# Epoch: 382, Train loss: 0.2026, Val loss: 0.2019
# Epoch: 384, Train loss: 0.1968, Val loss: 0.1910
# Epoch: 386, Train loss: 0.2034, Val loss: 0.2019
# Epoch: 388, Train loss: 0.2040, Val loss: 0.1876
# Epoch: 390, Train loss: 0.2121, Val loss: 0.1928
# Epoch: 392, Train loss: 0.2157, Val loss: 0.1872
# Epoch: 394, Train loss: 0.2275, Val loss: 0.2029
# Epoch: 396, Train loss: 0.2067, Val loss: 0.1971
# Epoch: 398, Train loss: 0.2304, Val loss: 0.2057
# Epoch: 400, Train loss: 0.2077, Val loss: 0.2018
# Epoch: 402, Train loss: 0.2096, Val loss: 0.1854
# Epoch: 404, Train loss: 0.2069, Val loss: 0.1949
# Epoch: 406, Train loss: 0.2180, Val loss: 0.2272
# Epoch: 408, Train loss: 0.2032, Val loss: 0.1981
# Epoch: 410, Train loss: 0.2140, Val loss: 0.2010
# Epoch: 412, Train loss: 0.2069, Val loss: 0.1866
# Epoch: 414, Train loss: 0.1975, Val loss: 0.2159
# Epoch: 416, Train loss: 0.2083, Val loss: 0.2326
# Epoch: 418, Train loss: 0.2212, Val loss: 0.2100
# Epoch: 420, Train loss: 0.1966, Val loss: 0.1842
# Epoch: 422, Train loss: 0.1959, Val loss: 0.2300
# Epoch: 424, Train loss: 0.2030, Val loss: 0.1858
# Epoch: 426, Train loss: 0.2012, Val loss: 0.2116
# Epoch: 428, Train loss: 0.1983, Val loss: 0.1836
# Epoch: 430, Train loss: 0.1998, Val loss: 0.1870
# Epoch: 432, Train loss: 0.2086, Val loss: 0.2306
# Epoch: 434, Train loss: 0.1960, Val loss: 0.1935
# Epoch: 436, Train loss: 0.2075, Val loss: 0.2008
# Epoch: 438, Train loss: 0.1868, Val loss: 0.2058
# Epoch: 440, Train loss: 0.2259, Val loss: 0.1836
# Epoch: 442, Train loss: 0.2196, Val loss: 0.2140
# Epoch: 444, Train loss: 0.1961, Val loss: 0.2304
# Epoch: 446, Train loss: 0.2145, Val loss: 0.2411
# Epoch: 448, Train loss: 0.2118, Val loss: 0.2034
# Epoch: 450, Train loss: 0.2006, Val loss: 0.1947
# Epoch: 452, Train loss: 0.2175, Val loss: 0.1956
# Epoch: 454, Train loss: 0.1918, Val loss: 0.1851
# Epoch: 456, Train loss: 0.1930, Val loss: 0.1888
# Epoch: 458, Train loss: 0.2000, Val loss: 0.1897
# Epoch: 460, Train loss: 0.1837, Val loss: 0.1890
# Epoch: 462, Train loss: 0.1917, Val loss: 0.1845
# Epoch: 464, Train loss: 0.1889, Val loss: 0.1944
# Epoch: 466, Train loss: 0.1920, Val loss: 0.1824
# Epoch: 468, Train loss: 0.2196, Val loss: 0.1931
# Epoch: 470, Train loss: 0.1904, Val loss: 0.1841
# Epoch: 472, Train loss: 0.1931, Val loss: 0.2079
# Epoch: 474, Train loss: 0.1941, Val loss: 0.1847
# Epoch: 476, Train loss: 0.1832, Val loss: 0.1992
# Epoch: 478, Train loss: 0.2345, Val loss: 0.1869
# Epoch: 480, Train loss: 0.2064, Val loss: 0.2330
# Epoch: 482, Train loss: 0.1881, Val loss: 0.1835
# Epoch: 484, Train loss: 0.1881, Val loss: 0.1842
# Epoch: 486, Train loss: 0.1881, Val loss: 0.1729
# Epoch: 488, Train loss: 0.1875, Val loss: 0.1706
# Epoch: 490, Train loss: 0.1783, Val loss: 0.1749
# Epoch: 492, Train loss: 0.1908, Val loss: 0.2029
# Epoch: 494, Train loss: 0.2064, Val loss: 0.1809
# Epoch: 496, Train loss: 0.1981, Val loss: 0.1748
# Epoch: 498, Train loss: 0.1965, Val loss: 0.1858
# Validation MSE: 0.1866, MAE: 0.3171

# %%
cation_gat_train_loss, cation_gat_val_loss, cation_gat_train_pred, cation_gat_train_true, cation_gat_val_pred, cation_gat_val_true, cation_gat_mse, cation_gat_mae = train_epochs(
    12, epochs, model_cation, cation_train_loader, cation_val_loader, "Cation_GAT_model_LUMO.pt"
)
# Out:
# Epoch: 0, Train loss: 3.6865, Val loss: 1.5626
# Epoch: 2, Train loss: 1.3340, Val loss: 0.9739
# Epoch: 4, Train loss: 0.8504, Val loss: 0.6565
# Epoch: 6, Train loss: 0.7664, Val loss: 0.6155
# Epoch: 8, Train loss: 0.7429, Val loss: 0.6039
# Epoch: 10, Train loss: 0.7315, Val loss: 0.6409
# Epoch: 12, Train loss: 0.6914, Val loss: 0.5407
# Epoch: 14, Train loss: 0.6717, Val loss: 0.5211
# Epoch: 16, Train loss: 0.6678, Val loss: 0.5799
# Epoch: 18, Train loss: 0.6137, Val loss: 0.4891
# Epoch: 20, Train loss: 0.5650, Val loss: 0.4559
# Epoch: 22, Train loss: 0.5725, Val loss: 0.4672
# Epoch: 24, Train loss: 0.5478, Val loss: 0.4354
# Epoch: 26, Train loss: 0.5383, Val loss: 0.4273
# Epoch: 28, Train loss: 0.5294, Val loss: 0.4081
# Epoch: 30, Train loss: 0.5031, Val loss: 0.4211
# Epoch: 32, Train loss: 0.5298, Val loss: 0.4033
# Epoch: 34, Train loss: 0.5045, Val loss: 0.4133
# Epoch: 36, Train loss: 0.5291, Val loss: 0.4198
# Epoch: 38, Train loss: 0.5136, Val loss: 0.4695
# Epoch: 40, Train loss: 0.5369, Val loss: 0.3844
# Epoch: 42, Train loss: 0.4730, Val loss: 0.4221
# Epoch: 44, Train loss: 0.4842, Val loss: 0.3769
# Epoch: 46, Train loss: 0.4984, Val loss: 0.3601
# Epoch: 48, Train loss: 0.4822, Val loss: 0.3918
# Epoch: 50, Train loss: 0.4690, Val loss: 0.3640
# Epoch: 52, Train loss: 0.4533, Val loss: 0.3600
# Epoch: 54, Train loss: 0.4433, Val loss: 0.3970
# Epoch: 56, Train loss: 0.4761, Val loss: 0.3495
# Epoch: 58, Train loss: 0.4439, Val loss: 0.3654
# Epoch: 60, Train loss: 0.4614, Val loss: 0.4073
# Epoch: 62, Train loss: 0.4605, Val loss: 0.3670
# Epoch: 64, Train loss: 0.4650, Val loss: 0.4023
# Epoch: 66, Train loss: 0.4414, Val loss: 0.3281
# Epoch: 68, Train loss: 0.4240, Val loss: 0.3195
# Epoch: 70, Train loss: 0.4222, Val loss: 0.3178
# Epoch: 72, Train loss: 0.4224, Val loss: 0.3709
# Epoch: 74, Train loss: 0.4112, Val loss: 0.3379
# Epoch: 76, Train loss: 0.3919, Val loss: 0.3383
# Epoch: 78, Train loss: 0.4476, Val loss: 0.3000
# Epoch: 80, Train loss: 0.4436, Val loss: 0.3445
# Epoch: 82, Train loss: 0.4110, Val loss: 0.3065
# Epoch: 84, Train loss: 0.3808, Val loss: 0.2903
# Epoch: 86, Train loss: 0.3986, Val loss: 0.3144
# Epoch: 88, Train loss: 0.3923, Val loss: 0.3090
# Epoch: 90, Train loss: 0.3784, Val loss: 0.2866
# Epoch: 92, Train loss: 0.4164, Val loss: 0.3078
# Epoch: 94, Train loss: 0.4025, Val loss: 0.3010
# Epoch: 96, Train loss: 0.3704, Val loss: 0.2823
# Epoch: 98, Train loss: 0.3738, Val loss: 0.2967
# Epoch: 100, Train loss: 0.3685, Val loss: 0.3059
# Epoch: 102, Train loss: 0.3639, Val loss: 0.2773
# Epoch: 104, Train loss: 0.3931, Val loss: 0.2845
# Epoch: 106, Train loss: 0.3912, Val loss: 0.3110
# Epoch: 108, Train loss: 0.3835, Val loss: 0.2940
# Epoch: 110, Train loss: 0.3666, Val loss: 0.3098
# Epoch: 112, Train loss: 0.3662, Val loss: 0.2691
# Epoch: 114, Train loss: 0.3891, Val loss: 0.2781
# Epoch: 116, Train loss: 0.3629, Val loss: 0.2750
# Epoch: 118, Train loss: 0.3750, Val loss: 0.2742
# Epoch: 120, Train loss: 0.3577, Val loss: 0.2675
# Epoch: 122, Train loss: 0.3512, Val loss: 0.2676
# Epoch: 124, Train loss: 0.3752, Val loss: 0.2722
# Epoch: 126, Train loss: 0.3630, Val loss: 0.2639
# Epoch: 128, Train loss: 0.3568, Val loss: 0.2811
# Epoch: 130, Train loss: 0.3630, Val loss: 0.2655
# Epoch: 132, Train loss: 0.3449, Val loss: 0.3259
# Epoch: 134, Train loss: 0.3483, Val loss: 0.3007
# Epoch: 136, Train loss: 0.3654, Val loss: 0.2635
# Epoch: 138, Train loss: 0.3466, Val loss: 0.2684
# Epoch: 140, Train loss: 0.3570, Val loss: 0.2794
# Epoch: 142, Train loss: 0.3731, Val loss: 0.2647
# Epoch: 144, Train loss: 0.3438, Val loss: 0.2667
# Epoch: 146, Train loss: 0.3604, Val loss: 0.2707
# Epoch: 148, Train loss: 0.3800, Val loss: 0.2834
# Epoch: 150, Train loss: 0.3469, Val loss: 0.2634
# Epoch: 152, Train loss: 0.3398, Val loss: 0.2658
# Epoch: 154, Train loss: 0.3429, Val loss: 0.2813
# Epoch: 156, Train loss: 0.3447, Val loss: 0.2593
# Epoch: 158, Train loss: 0.3547, Val loss: 0.2861
# Epoch: 160, Train loss: 0.3391, Val loss: 0.2943
# Epoch: 162, Train loss: 0.3328, Val loss: 0.2717
# Epoch: 164, Train loss: 0.3712, Val loss: 0.2924
# Epoch: 166, Train loss: 0.3367, Val loss: 0.2721
# Epoch: 168, Train loss: 0.3694, Val loss: 0.2595
# Epoch: 170, Train loss: 0.3471, Val loss: 0.2566
# Epoch: 172, Train loss: 0.3674, Val loss: 0.2522
# Epoch: 174, Train loss: 0.3344, Val loss: 0.2490
# Epoch: 176, Train loss: 0.3290, Val loss: 0.2790
# Epoch: 178, Train loss: 0.3386, Val loss: 0.2517
# Epoch: 180, Train loss: 0.3282, Val loss: 0.2518
# Epoch: 182, Train loss: 0.3432, Val loss: 0.2717
# Epoch: 184, Train loss: 0.3382, Val loss: 0.2524
# Epoch: 186, Train loss: 0.3281, Val loss: 0.2516
# Epoch: 188, Train loss: 0.3393, Val loss: 0.2439
# Epoch: 190, Train loss: 0.3498, Val loss: 0.2487
# Epoch: 192, Train loss: 0.3140, Val loss: 0.2360
# Epoch: 194, Train loss: 0.3061, Val loss: 0.2305
# Epoch: 196, Train loss: 0.3245, Val loss: 0.2320
# Epoch: 198, Train loss: 0.3351, Val loss: 0.2304
# Epoch: 200, Train loss: 0.3205, Val loss: 0.2182
# Epoch: 202, Train loss: 0.3056, Val loss: 0.2193
# Epoch: 204, Train loss: 0.3049, Val loss: 0.2529
# Epoch: 206, Train loss: 0.3118, Val loss: 0.2067
# Epoch: 208, Train loss: 0.3027, Val loss: 0.2410
# Epoch: 210, Train loss: 0.2864, Val loss: 0.1994
# Epoch: 212, Train loss: 0.2744, Val loss: 0.2177
# Epoch: 214, Train loss: 0.2819, Val loss: 0.1896
# Epoch: 216, Train loss: 0.2894, Val loss: 0.1933
# Epoch: 218, Train loss: 0.2799, Val loss: 0.1984
# Epoch: 220, Train loss: 0.2737, Val loss: 0.1816
# Epoch: 222, Train loss: 0.2752, Val loss: 0.1899
# Epoch: 224, Train loss: 0.2944, Val loss: 0.2195
# Epoch: 226, Train loss: 0.2747, Val loss: 0.2270
# Epoch: 228, Train loss: 0.2665, Val loss: 0.1796
# Epoch: 230, Train loss: 0.2661, Val loss: 0.1770
# Epoch: 232, Train loss: 0.2631, Val loss: 0.1769
# Epoch: 234, Train loss: 0.2929, Val loss: 0.1856
# Epoch: 236, Train loss: 0.2631, Val loss: 0.1762
# Epoch: 238, Train loss: 0.2542, Val loss: 0.1749
# Epoch: 240, Train loss: 0.2761, Val loss: 0.2039
# Epoch: 242, Train loss: 0.2563, Val loss: 0.1666
# Epoch: 244, Train loss: 0.2809, Val loss: 0.2210
# Epoch: 246, Train loss: 0.2600, Val loss: 0.1795
# Epoch: 248, Train loss: 0.2533, Val loss: 0.1663
# Epoch: 250, Train loss: 0.2837, Val loss: 0.2026
# Epoch: 252, Train loss: 0.2535, Val loss: 0.1585
# Epoch: 254, Train loss: 0.2762, Val loss: 0.2252
# Epoch: 256, Train loss: 0.2546, Val loss: 0.1689
# Epoch: 258, Train loss: 0.2586, Val loss: 0.1566
# Epoch: 260, Train loss: 0.2520, Val loss: 0.1581
# Epoch: 262, Train loss: 0.2588, Val loss: 0.1606
# Epoch: 264, Train loss: 0.2500, Val loss: 0.1590
# Epoch: 266, Train loss: 0.2696, Val loss: 0.1879
# Epoch: 268, Train loss: 0.2557, Val loss: 0.1565
# Epoch: 270, Train loss: 0.2536, Val loss: 0.1578
# Epoch: 272, Train loss: 0.2451, Val loss: 0.1524
# Epoch: 274, Train loss: 0.2404, Val loss: 0.1517
# Epoch: 276, Train loss: 0.2614, Val loss: 0.1592
# Epoch: 278, Train loss: 0.2502, Val loss: 0.1656
# Epoch: 280, Train loss: 0.2428, Val loss: 0.1472
# Epoch: 282, Train loss: 0.2354, Val loss: 0.1518
# Epoch: 284, Train loss: 0.2516, Val loss: 0.1723
# Epoch: 286, Train loss: 0.2564, Val loss: 0.1583
# Epoch: 288, Train loss: 0.2401, Val loss: 0.1439
# Epoch: 290, Train loss: 0.2444, Val loss: 0.1653
# Epoch: 292, Train loss: 0.2384, Val loss: 0.1447
# Epoch: 294, Train loss: 0.2631, Val loss: 0.1715
# Epoch: 296, Train loss: 0.2431, Val loss: 0.1513
# Epoch: 298, Train loss: 0.2510, Val loss: 0.1473
# Epoch: 300, Train loss: 0.2430, Val loss: 0.1902
# Epoch: 302, Train loss: 0.2485, Val loss: 0.1528
# Epoch: 304, Train loss: 0.2438, Val loss: 0.1695
# Epoch: 306, Train loss: 0.2368, Val loss: 0.1526
# Epoch: 308, Train loss: 0.2354, Val loss: 0.1694
# Epoch: 310, Train loss: 0.2517, Val loss: 0.1393
# Epoch: 312, Train loss: 0.2516, Val loss: 0.1501
# Epoch: 314, Train loss: 0.2514, Val loss: 0.1456
# Epoch: 316, Train loss: 0.2319, Val loss: 0.1841
# Epoch: 318, Train loss: 0.2574, Val loss: 0.1594
# Epoch: 320, Train loss: 0.2352, Val loss: 0.1498
# Epoch: 322, Train loss: 0.2320, Val loss: 0.1456
# Epoch: 324, Train loss: 0.2285, Val loss: 0.1589
# Epoch: 326, Train loss: 0.2372, Val loss: 0.1531
# Epoch: 328, Train loss: 0.2317, Val loss: 0.1490
# Epoch: 330, Train loss: 0.2363, Val loss: 0.1537
# Epoch: 332, Train loss: 0.2571, Val loss: 0.1576
# Epoch: 334, Train loss: 0.2299, Val loss: 0.1363
# Epoch: 336, Train loss: 0.2392, Val loss: 0.1452
# Epoch: 338, Train loss: 0.2468, Val loss: 0.1549
# Epoch: 340, Train loss: 0.2283, Val loss: 0.1602
# Epoch: 342, Train loss: 0.2235, Val loss: 0.1653
# Epoch: 344, Train loss: 0.2490, Val loss: 0.1616
# Epoch: 346, Train loss: 0.2461, Val loss: 0.1562
# Epoch: 348, Train loss: 0.2389, Val loss: 0.1409
# Epoch: 350, Train loss: 0.2354, Val loss: 0.1757
# Epoch: 352, Train loss: 0.2296, Val loss: 0.1740
# Epoch: 354, Train loss: 0.2237, Val loss: 0.1497
# Epoch: 356, Train loss: 0.2266, Val loss: 0.1399
# Epoch: 358, Train loss: 0.2332, Val loss: 0.1463
# Epoch: 360, Train loss: 0.2351, Val loss: 0.1425
# Epoch: 362, Train loss: 0.2284, Val loss: 0.1448
# Epoch: 364, Train loss: 0.2338, Val loss: 0.1458
# Epoch: 366, Train loss: 0.2494, Val loss: 0.1470
# Epoch: 368, Train loss: 0.2264, Val loss: 0.1573
# Epoch: 370, Train loss: 0.2301, Val loss: 0.1508
# Epoch: 372, Train loss: 0.2283, Val loss: 0.1518
# Epoch: 374, Train loss: 0.2249, Val loss: 0.1414
# Epoch: 376, Train loss: 0.2235, Val loss: 0.1395
# Epoch: 378, Train loss: 0.2311, Val loss: 0.1645
# Epoch: 380, Train loss: 0.2198, Val loss: 0.1366
# Epoch: 382, Train loss: 0.2291, Val loss: 0.1682
# Epoch: 384, Train loss: 0.2334, Val loss: 0.1672
# Epoch: 386, Train loss: 0.2226, Val loss: 0.1372
# Epoch: 388, Train loss: 0.2419, Val loss: 0.1412
# Epoch: 390, Train loss: 0.2215, Val loss: 0.1509
# Epoch: 392, Train loss: 0.2308, Val loss: 0.1804
# Epoch: 394, Train loss: 0.2188, Val loss: 0.1352
# Epoch: 396, Train loss: 0.2229, Val loss: 0.1489
# Epoch: 398, Train loss: 0.2205, Val loss: 0.1501
# Epoch: 400, Train loss: 0.2291, Val loss: 0.1403
# Epoch: 402, Train loss: 0.2119, Val loss: 0.1481
# Epoch: 404, Train loss: 0.2297, Val loss: 0.1508
# Epoch: 406, Train loss: 0.2109, Val loss: 0.1451
# Epoch: 408, Train loss: 0.2191, Val loss: 0.1528
# Epoch: 410, Train loss: 0.2103, Val loss: 0.1350
# Epoch: 412, Train loss: 0.2154, Val loss: 0.1747
# Epoch: 414, Train loss: 0.2282, Val loss: 0.1469
# Epoch: 416, Train loss: 0.2241, Val loss: 0.1600
# Epoch: 418, Train loss: 0.2163, Val loss: 0.1355
# Epoch: 420, Train loss: 0.2206, Val loss: 0.1418
# Epoch: 422, Train loss: 0.2125, Val loss: 0.1394
# Epoch: 424, Train loss: 0.2205, Val loss: 0.1637
# Epoch: 426, Train loss: 0.2103, Val loss: 0.1367
# Epoch: 428, Train loss: 0.2320, Val loss: 0.1348
# Epoch: 430, Train loss: 0.2230, Val loss: 0.1544
# Epoch: 432, Train loss: 0.2499, Val loss: 0.1479
# Epoch: 434, Train loss: 0.2285, Val loss: 0.1474
# Epoch: 436, Train loss: 0.2202, Val loss: 0.1345
# Epoch: 438, Train loss: 0.2123, Val loss: 0.1385
# Epoch: 440, Train loss: 0.2213, Val loss: 0.1494
# Epoch: 442, Train loss: 0.2456, Val loss: 0.1385
# Epoch: 444, Train loss: 0.2041, Val loss: 0.1346
# Epoch: 446, Train loss: 0.2273, Val loss: 0.1428
# Epoch: 448, Train loss: 0.2219, Val loss: 0.1431
# Epoch: 450, Train loss: 0.2098, Val loss: 0.1514
# Epoch: 452, Train loss: 0.2117, Val loss: 0.1484
# Epoch: 454, Train loss: 0.2098, Val loss: 0.1445
# Epoch: 456, Train loss: 0.2085, Val loss: 0.1405
# Epoch: 458, Train loss: 0.2113, Val loss: 0.1712
# Epoch: 460, Train loss: 0.2097, Val loss: 0.1438
# Epoch: 462, Train loss: 0.2200, Val loss: 0.1565
# Epoch: 464, Train loss: 0.2120, Val loss: 0.1456
# Epoch: 466, Train loss: 0.2015, Val loss: 0.1324
# Epoch: 468, Train loss: 0.2204, Val loss: 0.1468
# Epoch: 470, Train loss: 0.2040, Val loss: 0.1546
# Epoch: 472, Train loss: 0.2078, Val loss: 0.1315
# Epoch: 474, Train loss: 0.2126, Val loss: 0.1278
# Epoch: 476, Train loss: 0.2140, Val loss: 0.1333
# Epoch: 478, Train loss: 0.2132, Val loss: 0.1354
# Epoch: 480, Train loss: 0.2262, Val loss: 0.1385
# Epoch: 482, Train loss: 0.2144, Val loss: 0.1408
# Epoch: 484, Train loss: 0.2241, Val loss: 0.1460
# Epoch: 486, Train loss: 0.2097, Val loss: 0.1523
# Epoch: 488, Train loss: 0.2207, Val loss: 0.1329
# Epoch: 490, Train loss: 0.2252, Val loss: 0.1374
# Epoch: 492, Train loss: 0.2270, Val loss: 0.1408
# Epoch: 494, Train loss: 0.2141, Val loss: 0.1353
# Epoch: 496, Train loss: 0.2199, Val loss: 0.1449
# Epoch: 498, Train loss: 0.2148, Val loss: 0.2019
# Validation MSE: 0.1321, MAE: 0.2602

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

def plot_loss(gcn_train_loss, gcn_val_loss):
    # Plot the loss curve
    plt.plot(gcn_train_loss, label="Train loss (GAT)")
    plt.plot(gcn_val_loss, label="Val loss (GAT)")
    plt.legend()  # Add legend
    # plt.ylim(0, 2)  # Set Y-axis range
    plt.ylabel("Loss")  # Set Y-axis label
    plt.xlabel("Epoch")  # Set X-axis label
    plt.title("Model Loss")  # Set title
    plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))  # Set X-axis ticks as integers
    plt.show()  # Display the plot

def plot_targets(pred, ground_truth, mse, mae, save_path="GAT_val.png"):
    
    from sklearn.metrics import r2_score
    
    # Calculate R² (coefficient of determination)
    r2 = r2_score(ground_truth, pred)
    # Plot scatter plot comparing predicted values and ground truth
    f, ax = plt.subplots(figsize=(1.75, 1.75))  # Create figure and axis objects
    ax.scatter(pred, ground_truth, s=0.5)  # Plot scatter points
    ax.axline((1, 1), slope=1, color="red", linestyle="--")  # Add reference line
    plt.xlabel("Predicted Value")  # Set X-axis label
    plt.ylabel("Ground Truth")  # Set Y-axis label
    # plt.title("Ground Truth vs Prediction")  # Set title

    # Display MAE and MSE in the top left corner
    text_str = f"MAE = {mae:.2f}\nMSE = {mse:.2f}\nR² = {r2:.2f}\nParameters = {count_parameters(model)}"
    plt.text(
        0.05, 0.95, text_str,
        transform=ax.transAxes,  # Use axis coordinates for positioning
        fontsize=7, color="black",
        verticalalignment="top", horizontalalignment="left"
    )
    # Save the image
    plt.savefig(save_path, dpi=300, bbox_inches="tight")  # Save the image with 300 DPI resolution
    plt.show()  # Display the plot

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

def plot_cation_anion_targets(cation_pred, cation_ground_truth, anion_pred, anion_ground_truth, title="GAT", save_path="GAT_cation_anion_val.png"):
    # Calculate the number of model parameters
    parameters = count_parameters(model)
    
    # Create figure and axis objects
    fig, ax = plt.subplots(figsize=(1.75, 1.75))
    
    # Plot scatter points for cations (red)
    ax.scatter(cation_pred, cation_ground_truth, s=0.5, color='#f7c0c5', label='Cation')
    
    # Plot scatter points for anions (blue)
    ax.scatter(anion_pred, anion_ground_truth, s=0.5, color='#bfcfe4', label='Anion')
    
    # Add reference line y = x
    ax.axline((0, 0), slope=1, color="gray", linestyle="--")
    
    # Set axis labels
    plt.xlabel("Predicted Value")
    plt.ylabel("Ground Truth")
    
    # Display legend
    ax.legend(loc='lower right')
    plt.title(title)
    
    # Display the number of model parameters in the top left corner
    text_str = f"Parameters = {parameters}"
    plt.text(
        0.05, 0.95, text_str,
        transform=ax.transAxes,
        fontsize=7, color="black",
        verticalalignment="top", horizontalalignment="left"
    )
    
    # Save the plot
    plt.savefig(save_path, dpi=300, bbox_inches="tight")
    plt.show()

# %%
plot_loss(anion_gat_train_loss, anion_gat_val_loss)

# %%
plot_loss(cation_gat_train_loss, cation_gat_val_loss)

# %%
plot_cation_anion_targets(cation_gat_val_pred, cation_gat_val_true, anion_gat_val_pred,
                          anion_gat_val_true, title="GAT", save_path="GAT_cation_anion_val.png")

# %%
plot_targets(anion_gat_val_pred, anion_gat_val_true, anion_gat_mse, anion_gat_mae, save_path="anion_GAT_val_HOMO.png")

# %%
plot_targets(cation_gat_val_pred, cation_gat_val_true, cation_gat_mse, cation_gat_mae, save_path="cation_GAT_val_LUMO.png")

# %% [markdown]
# # 25% train dataset

# %%
anion_25_load_train_dataset_path = 'dataset/train_anion_data_list_25.pt'
anion_25_loaded_train_data_list = load_data_list(anion_25_load_train_dataset_path)
anion_25_train_loader = DataLoader(anion_25_loaded_train_data_list, batch_size=128, shuffle=True)  

cation_25_load_train_dataset_path = 'dataset/train_cation_data_list_25.pt'
cation_25_loaded_train_data_list = load_data_list(cation_25_load_train_dataset_path)
cation_25_train_loader = DataLoader(cation_25_loaded_train_data_list, batch_size=128, shuffle=True)

# %%
# Train the GCN model with the number of epochs set to 100
epochs = 500

# Initialize the GCN model with hidden layer dimension set to 256
model_anion_25 = GAT(in_channels=5, hidden_channels=256).to(device)  
model_cation_25 = GAT(in_channels=5, hidden_channels=256).to(device)

# %%
anion_gat_train_loss_25, anion_gat_val_loss_25, anion_gat_train_pred_25, anion_gat_train_true_25, anion_gat_val_pred_25, anion_gat_val_true_25, anion_gat_mse_25, anion_gat_mae_25 = train_epochs(
    11, epochs,model_anion_25, anion_25_train_loader, anion_val_loader, "Anion_GAT_model_HOMO_25.pt"
)
# Out:
# Epoch: 0, Train loss: 3.3759, Val loss: 1.0977
# Epoch: 2, Train loss: 1.3168, Val loss: 1.1607
# Epoch: 4, Train loss: 1.1650, Val loss: 1.0196
# Epoch: 6, Train loss: 1.0887, Val loss: 0.8913
# Epoch: 8, Train loss: 1.0156, Val loss: 0.8123
# Epoch: 10, Train loss: 0.9641, Val loss: 0.7812
# Epoch: 12, Train loss: 0.9197, Val loss: 0.7748
# Epoch: 14, Train loss: 0.9185, Val loss: 0.7333
# Epoch: 16, Train loss: 0.8549, Val loss: 0.7088
# Epoch: 18, Train loss: 0.9077, Val loss: 0.7072
# Epoch: 20, Train loss: 0.8022, Val loss: 0.7054
# Epoch: 22, Train loss: 0.8840, Val loss: 0.7033
# Epoch: 24, Train loss: 0.8393, Val loss: 0.7032
# Epoch: 26, Train loss: 0.8128, Val loss: 0.7030
# Epoch: 28, Train loss: 0.8271, Val loss: 0.7016
# Epoch: 30, Train loss: 0.7915, Val loss: 0.7039
# Epoch: 32, Train loss: 0.8389, Val loss: 0.7042
# Epoch: 34, Train loss: 0.8450, Val loss: 0.7646
# Epoch: 36, Train loss: 0.8516, Val loss: 0.7609
# Epoch: 38, Train loss: 0.8476, Val loss: 0.7666
# Epoch: 40, Train loss: 0.8229, Val loss: 0.7006
# Epoch: 42, Train loss: 0.8162, Val loss: 0.6892
# Epoch: 44, Train loss: 0.7775, Val loss: 0.6891
# Epoch: 46, Train loss: 0.8336, Val loss: 0.6884
# Epoch: 48, Train loss: 0.8143, Val loss: 0.6933
# Epoch: 50, Train loss: 0.7920, Val loss: 0.6834
# Epoch: 52, Train loss: 0.7931, Val loss: 0.6818
# Epoch: 54, Train loss: 0.7774, Val loss: 0.6837
# Epoch: 56, Train loss: 0.8102, Val loss: 0.6788
# Epoch: 58, Train loss: 0.7768, Val loss: 0.6815
# Epoch: 60, Train loss: 0.7557, Val loss: 0.6751
# Epoch: 62, Train loss: 0.8021, Val loss: 0.6734
# Epoch: 64, Train loss: 0.8091, Val loss: 0.7064
# Epoch: 66, Train loss: 0.8579, Val loss: 0.7278
# Epoch: 68, Train loss: 0.9025, Val loss: 0.7010
# Epoch: 70, Train loss: 0.7524, Val loss: 0.6667
# Epoch: 72, Train loss: 0.7625, Val loss: 0.6696
# Epoch: 74, Train loss: 0.7895, Val loss: 0.6704
# Epoch: 76, Train loss: 0.7717, Val loss: 0.6598
# Epoch: 78, Train loss: 0.7718, Val loss: 0.6579
# Epoch: 80, Train loss: 0.7842, Val loss: 0.6838
# Epoch: 82, Train loss: 0.7641, Val loss: 0.6553
# Epoch: 84, Train loss: 0.7509, Val loss: 0.6616
# Epoch: 86, Train loss: 0.7829, Val loss: 0.6506
# Epoch: 88, Train loss: 0.7906, Val loss: 0.6496
# Epoch: 90, Train loss: 0.7738, Val loss: 0.6643
# Epoch: 92, Train loss: 0.7300, Val loss: 0.6802
# Epoch: 94, Train loss: 0.7162, Val loss: 0.6690
# Epoch: 96, Train loss: 0.7932, Val loss: 0.6604
# Epoch: 98, Train loss: 0.7350, Val loss: 0.6438
# Epoch: 100, Train loss: 0.7173, Val loss: 0.6475
# Epoch: 102, Train loss: 0.7333, Val loss: 0.6398
# Epoch: 104, Train loss: 0.7549, Val loss: 0.6360
# Epoch: 106, Train loss: 0.7690, Val loss: 0.6427
# Epoch: 108, Train loss: 0.7261, Val loss: 0.6347
# Epoch: 110, Train loss: 0.7482, Val loss: 0.6333
# Epoch: 112, Train loss: 0.6983, Val loss: 0.6324
# Epoch: 114, Train loss: 0.7372, Val loss: 0.6283
# Epoch: 116, Train loss: 0.7646, Val loss: 0.6275
# Epoch: 118, Train loss: 0.7975, Val loss: 0.6389
# Epoch: 120, Train loss: 0.7892, Val loss: 0.6358
# Epoch: 122, Train loss: 0.7008, Val loss: 0.6523
# Epoch: 124, Train loss: 0.7264, Val loss: 0.6801
# Epoch: 126, Train loss: 0.7772, Val loss: 0.6326
# Epoch: 128, Train loss: 0.7605, Val loss: 0.6228
# Epoch: 130, Train loss: 0.7049, Val loss: 0.6207
# Epoch: 132, Train loss: 0.7179, Val loss: 0.6224
# Epoch: 134, Train loss: 0.7292, Val loss: 0.6193
# Epoch: 136, Train loss: 0.7339, Val loss: 0.6388
# Epoch: 138, Train loss: 0.7406, Val loss: 0.6441
# Epoch: 140, Train loss: 0.6965, Val loss: 0.6679
# Epoch: 142, Train loss: 0.7465, Val loss: 0.6337
# Epoch: 144, Train loss: 0.7118, Val loss: 0.6134
# Epoch: 146, Train loss: 0.7288, Val loss: 0.6129
# Epoch: 148, Train loss: 0.7479, Val loss: 0.6138
# Epoch: 150, Train loss: 0.7366, Val loss: 0.6144
# Epoch: 152, Train loss: 0.7033, Val loss: 0.6224
# Epoch: 154, Train loss: 0.7332, Val loss: 0.6108
# Epoch: 156, Train loss: 0.7280, Val loss: 0.6259
# Epoch: 158, Train loss: 0.6896, Val loss: 0.6411
# Epoch: 160, Train loss: 0.6903, Val loss: 0.6168
# Epoch: 162, Train loss: 0.7010, Val loss: 0.6071
# Epoch: 164, Train loss: 0.6994, Val loss: 0.6166
# Epoch: 166, Train loss: 0.6900, Val loss: 0.6062
# Epoch: 168, Train loss: 0.6707, Val loss: 0.6017
# Epoch: 170, Train loss: 0.6672, Val loss: 0.5989
# Epoch: 172, Train loss: 0.6683, Val loss: 0.5999
# Epoch: 174, Train loss: 0.6612, Val loss: 0.6026
# Epoch: 176, Train loss: 0.6909, Val loss: 0.6045
# Epoch: 178, Train loss: 0.6990, Val loss: 0.6013
# Epoch: 180, Train loss: 0.6975, Val loss: 0.6271
# Epoch: 182, Train loss: 0.6508, Val loss: 0.6248
# Epoch: 184, Train loss: 0.7042, Val loss: 0.6095
# Epoch: 186, Train loss: 0.7112, Val loss: 0.5988
# Epoch: 188, Train loss: 0.6801, Val loss: 0.5922
# Epoch: 190, Train loss: 0.6875, Val loss: 0.5927
# Epoch: 192, Train loss: 0.6622, Val loss: 0.5858
# Epoch: 194, Train loss: 0.6908, Val loss: 0.5794
# Epoch: 196, Train loss: 0.6950, Val loss: 0.5782
# Epoch: 198, Train loss: 0.6624, Val loss: 0.5750
# Epoch: 200, Train loss: 0.6976, Val loss: 0.6019
# Epoch: 202, Train loss: 0.6658, Val loss: 0.5737
# Epoch: 204, Train loss: 0.7668, Val loss: 0.6027
# Epoch: 206, Train loss: 0.6791, Val loss: 0.5815
# Epoch: 208, Train loss: 0.6861, Val loss: 0.5684
# Epoch: 210, Train loss: 0.6795, Val loss: 0.5747
# Epoch: 212, Train loss: 0.6473, Val loss: 0.5803
# Epoch: 214, Train loss: 0.6718, Val loss: 0.5665
# Epoch: 216, Train loss: 0.6476, Val loss: 0.5595
# Epoch: 218, Train loss: 0.6568, Val loss: 0.5712
# Epoch: 220, Train loss: 0.6721, Val loss: 0.5770
# Epoch: 222, Train loss: 0.6599, Val loss: 0.5480
# Epoch: 224, Train loss: 0.6142, Val loss: 0.5467
# Epoch: 226, Train loss: 0.6217, Val loss: 0.5544
# Epoch: 228, Train loss: 0.6529, Val loss: 0.5417
# Epoch: 230, Train loss: 0.6219, Val loss: 0.5546
# Epoch: 232, Train loss: 0.6794, Val loss: 0.6290
# Epoch: 234, Train loss: 0.6997, Val loss: 0.5425
# Epoch: 236, Train loss: 0.6957, Val loss: 0.5845
# Epoch: 238, Train loss: 0.6164, Val loss: 0.5411
# Epoch: 240, Train loss: 0.6554, Val loss: 0.5727
# Epoch: 242, Train loss: 0.6774, Val loss: 0.5981
# Epoch: 244, Train loss: 0.6544, Val loss: 0.5353
# Epoch: 246, Train loss: 0.6462, Val loss: 0.5393
# Epoch: 248, Train loss: 0.6222, Val loss: 0.5925
# Epoch: 250, Train loss: 0.6236, Val loss: 0.5265
# Epoch: 252, Train loss: 0.6452, Val loss: 0.5304
# Epoch: 254, Train loss: 0.6142, Val loss: 0.5086
# Epoch: 256, Train loss: 0.6009, Val loss: 0.5793
# Epoch: 258, Train loss: 0.6334, Val loss: 0.5122
# Epoch: 260, Train loss: 0.6036, Val loss: 0.5046
# Epoch: 262, Train loss: 0.5681, Val loss: 0.5344
# Epoch: 264, Train loss: 0.6198, Val loss: 0.5268
# Epoch: 266, Train loss: 0.5928, Val loss: 0.5274
# Epoch: 268, Train loss: 0.5598, Val loss: 0.6934
# Epoch: 270, Train loss: 0.6784, Val loss: 0.6719
# Epoch: 272, Train loss: 0.6789, Val loss: 0.5088
# Epoch: 274, Train loss: 0.5779, Val loss: 0.4860
# Epoch: 276, Train loss: 0.5956, Val loss: 0.5170
# Epoch: 278, Train loss: 0.5831, Val loss: 0.6067
# Epoch: 280, Train loss: 0.5517, Val loss: 0.5091
# Epoch: 282, Train loss: 0.5419, Val loss: 0.4996
# Epoch: 284, Train loss: 0.5282, Val loss: 0.4793
# Epoch: 286, Train loss: 0.5287, Val loss: 0.4779
# Epoch: 288, Train loss: 0.4957, Val loss: 0.4878
# Epoch: 290, Train loss: 0.5097, Val loss: 0.4933
# Epoch: 292, Train loss: 0.4845, Val loss: 0.4765
# Epoch: 294, Train loss: 0.5125, Val loss: 0.4751
# Epoch: 296, Train loss: 0.5806, Val loss: 0.4766
# Epoch: 298, Train loss: 0.4726, Val loss: 0.4896
# Epoch: 300, Train loss: 0.5542, Val loss: 0.4937
# Epoch: 302, Train loss: 0.5184, Val loss: 0.4835
# Epoch: 304, Train loss: 0.5027, Val loss: 0.4542
# Epoch: 306, Train loss: 0.4756, Val loss: 0.4786
# Epoch: 308, Train loss: 0.4757, Val loss: 0.4434
# Epoch: 310, Train loss: 0.4660, Val loss: 0.4638
# Epoch: 312, Train loss: 0.4924, Val loss: 0.4940
# Epoch: 314, Train loss: 0.4833, Val loss: 0.5062
# Epoch: 316, Train loss: 0.4507, Val loss: 0.4953
# Epoch: 318, Train loss: 0.5258, Val loss: 0.4420
# Epoch: 320, Train loss: 0.5552, Val loss: 0.4482
# Epoch: 322, Train loss: 0.4706, Val loss: 0.4485
# Epoch: 324, Train loss: 0.4424, Val loss: 0.4773
# Epoch: 326, Train loss: 0.4317, Val loss: 0.4895
# Epoch: 328, Train loss: 0.4418, Val loss: 0.4491
# Epoch: 330, Train loss: 0.4239, Val loss: 0.4387
# Epoch: 332, Train loss: 0.4383, Val loss: 0.4330
# Epoch: 334, Train loss: 0.4418, Val loss: 0.4597
# Epoch: 336, Train loss: 0.4489, Val loss: 0.4390
# Epoch: 338, Train loss: 0.4123, Val loss: 0.4291
# Epoch: 340, Train loss: 0.4259, Val loss: 0.4896
# Epoch: 342, Train loss: 0.4507, Val loss: 0.4546
# Epoch: 344, Train loss: 0.4213, Val loss: 0.4364
# Epoch: 346, Train loss: 0.3871, Val loss: 0.4204
# Epoch: 348, Train loss: 0.4168, Val loss: 0.4112
# Epoch: 350, Train loss: 0.4329, Val loss: 0.5016
# Epoch: 352, Train loss: 0.4369, Val loss: 0.4743
# Epoch: 354, Train loss: 0.4098, Val loss: 0.6136
# Epoch: 356, Train loss: 0.4625, Val loss: 0.4130
# Epoch: 358, Train loss: 0.4262, Val loss: 0.4240
# Epoch: 360, Train loss: 0.4075, Val loss: 0.4459
# Epoch: 362, Train loss: 0.4099, Val loss: 0.4326
# Epoch: 364, Train loss: 0.4153, Val loss: 0.4203
# Epoch: 366, Train loss: 0.4152, Val loss: 0.4637
# Epoch: 368, Train loss: 0.4460, Val loss: 0.4282
# Epoch: 370, Train loss: 0.4060, Val loss: 0.4197
# Epoch: 372, Train loss: 0.4423, Val loss: 0.4223
# Epoch: 374, Train loss: 0.4125, Val loss: 0.4228
# Epoch: 376, Train loss: 0.4184, Val loss: 0.4327
# Epoch: 378, Train loss: 0.3926, Val loss: 0.4562
# Epoch: 380, Train loss: 0.4141, Val loss: 0.4146
# Epoch: 382, Train loss: 0.4022, Val loss: 0.4839
# Epoch: 384, Train loss: 0.4158, Val loss: 0.4765
# Epoch: 386, Train loss: 0.4264, Val loss: 0.4192
# Epoch: 388, Train loss: 0.3857, Val loss: 0.4071
# Epoch: 390, Train loss: 0.4383, Val loss: 0.4434
# Epoch: 392, Train loss: 0.3799, Val loss: 0.4085
# Epoch: 394, Train loss: 0.3780, Val loss: 0.3993
# Epoch: 396, Train loss: 0.3810, Val loss: 0.4980
# Epoch: 398, Train loss: 0.4363, Val loss: 0.4227
# Epoch: 400, Train loss: 0.3936, Val loss: 0.4139
# Epoch: 402, Train loss: 0.3759, Val loss: 0.3967
# Epoch: 404, Train loss: 0.3982, Val loss: 0.4228
# Epoch: 406, Train loss: 0.3879, Val loss: 0.3935
# Epoch: 408, Train loss: 0.3466, Val loss: 0.3992
# Epoch: 410, Train loss: 0.3637, Val loss: 0.4252
# Epoch: 412, Train loss: 0.3866, Val loss: 0.3895
# Epoch: 414, Train loss: 0.3744, Val loss: 0.4122
# Epoch: 416, Train loss: 0.3870, Val loss: 0.3897
# Epoch: 418, Train loss: 0.3798, Val loss: 0.4102
# Epoch: 420, Train loss: 0.4111, Val loss: 0.4227
# Epoch: 422, Train loss: 0.4009, Val loss: 0.3870
# Epoch: 424, Train loss: 0.3695, Val loss: 0.3887
# Epoch: 426, Train loss: 0.3709, Val loss: 0.3893
# Epoch: 428, Train loss: 0.3552, Val loss: 0.4023
# Epoch: 430, Train loss: 0.3516, Val loss: 0.3895
# Epoch: 432, Train loss: 0.3643, Val loss: 0.3855
# Epoch: 434, Train loss: 0.3718, Val loss: 0.3832
# Epoch: 436, Train loss: 0.3821, Val loss: 0.4270
# Epoch: 438, Train loss: 0.3563, Val loss: 0.4421
# Epoch: 440, Train loss: 0.3973, Val loss: 0.4091
# Epoch: 442, Train loss: 0.3961, Val loss: 0.4031
# Epoch: 444, Train loss: 0.3527, Val loss: 0.4482
# Epoch: 446, Train loss: 0.3818, Val loss: 0.3841
# Epoch: 448, Train loss: 0.3655, Val loss: 0.3967
# Epoch: 450, Train loss: 0.3583, Val loss: 0.4095
# Epoch: 452, Train loss: 0.3710, Val loss: 0.3959
# Epoch: 454, Train loss: 0.3296, Val loss: 0.3848
# Epoch: 456, Train loss: 0.3495, Val loss: 0.3870
# Epoch: 458, Train loss: 0.3684, Val loss: 0.3905
# Epoch: 460, Train loss: 0.3609, Val loss: 0.3931
# Epoch: 462, Train loss: 0.3703, Val loss: 0.3948
# Epoch: 464, Train loss: 0.3397, Val loss: 0.4645
# Epoch: 466, Train loss: 0.4192, Val loss: 0.4061
# Epoch: 468, Train loss: 0.3691, Val loss: 0.4080
# Epoch: 470, Train loss: 0.3407, Val loss: 0.4469
# Epoch: 472, Train loss: 0.3759, Val loss: 0.3876
# Epoch: 474, Train loss: 0.3504, Val loss: 0.3916
# Epoch: 476, Train loss: 0.3774, Val loss: 0.4981
# Epoch: 478, Train loss: 0.3763, Val loss: 0.3799
# Epoch: 480, Train loss: 0.3220, Val loss: 0.3858
# Epoch: 482, Train loss: 0.3477, Val loss: 0.3851
# Epoch: 484, Train loss: 0.3882, Val loss: 0.4026
# Epoch: 486, Train loss: 0.3426, Val loss: 0.3729
# Epoch: 488, Train loss: 0.3456, Val loss: 0.4018
# Epoch: 490, Train loss: 0.3605, Val loss: 0.3948
# Epoch: 492, Train loss: 0.3539, Val loss: 0.3744
# Epoch: 494, Train loss: 0.3745, Val loss: 0.3802
# Epoch: 496, Train loss: 0.3443, Val loss: 0.3917
# Epoch: 498, Train loss: 0.3527, Val loss: 0.4017
# Validation MSE: 0.4291, MAE: 0.5401

# %%
cation_gat_train_loss_25, cation_gat_val_loss_25, cation_gat_train_pred_25, cation_gat_train_true_25, cation_gat_val_pred_25, cation_gat_val_true_25, cation_gat_mse_25, cation_gat_mae_25 = train_epochs(
    12, epochs,model_cation_25, cation_25_train_loader, cation_val_loader, "Cation_GAT_model_LUMO_25.pt"
)
# Out:
# Epoch: 0, Train loss: 7.1461, Val loss: 2.9924
# Epoch: 2, Train loss: 2.0811, Val loss: 2.0314
# Epoch: 4, Train loss: 1.7996, Val loss: 1.5242
# Epoch: 6, Train loss: 1.6096, Val loss: 1.4232
# Epoch: 8, Train loss: 1.4137, Val loss: 1.2021
# Epoch: 10, Train loss: 1.1427, Val loss: 0.9624
# Epoch: 12, Train loss: 0.9411, Val loss: 0.7863
# Epoch: 14, Train loss: 0.8716, Val loss: 0.7942
# Epoch: 16, Train loss: 0.7933, Val loss: 0.6962
# Epoch: 18, Train loss: 0.8237, Val loss: 0.6799
# Epoch: 20, Train loss: 0.7887, Val loss: 0.6626
# Epoch: 22, Train loss: 0.7798, Val loss: 0.6665
# Epoch: 24, Train loss: 0.7751, Val loss: 0.6309
# Epoch: 26, Train loss: 0.7265, Val loss: 0.6218
# Epoch: 28, Train loss: 0.7935, Val loss: 0.6268
# Epoch: 30, Train loss: 0.7138, Val loss: 0.6297
# Epoch: 32, Train loss: 0.6881, Val loss: 0.6043
# Epoch: 34, Train loss: 0.7188, Val loss: 0.5942
# Epoch: 36, Train loss: 0.7196, Val loss: 0.5804
# Epoch: 38, Train loss: 0.7135, Val loss: 0.5729
# Epoch: 40, Train loss: 0.6455, Val loss: 0.5864
# Epoch: 42, Train loss: 0.6583, Val loss: 0.5595
# Epoch: 44, Train loss: 0.6732, Val loss: 0.5490
# Epoch: 46, Train loss: 0.6186, Val loss: 0.5404
# Epoch: 48, Train loss: 0.6112, Val loss: 0.5324
# Epoch: 50, Train loss: 0.6347, Val loss: 0.5783
# Epoch: 52, Train loss: 0.5736, Val loss: 0.5277
# Epoch: 54, Train loss: 0.6083, Val loss: 0.5133
# Epoch: 56, Train loss: 0.5832, Val loss: 0.5554
# Epoch: 58, Train loss: 0.6022, Val loss: 0.5012
# Epoch: 60, Train loss: 0.6751, Val loss: 0.4957
# Epoch: 62, Train loss: 0.6100, Val loss: 0.5606
# Epoch: 64, Train loss: 0.6043, Val loss: 0.5089
# Epoch: 66, Train loss: 0.5754, Val loss: 0.4962
# Epoch: 68, Train loss: 0.5719, Val loss: 0.4837
# Epoch: 70, Train loss: 0.5600, Val loss: 0.4792
# Epoch: 72, Train loss: 0.5404, Val loss: 0.4771
# Epoch: 74, Train loss: 0.5620, Val loss: 0.4743
# Epoch: 76, Train loss: 0.5622, Val loss: 0.4818
# Epoch: 78, Train loss: 0.5247, Val loss: 0.4794
# Epoch: 80, Train loss: 0.5355, Val loss: 0.4917
# Epoch: 82, Train loss: 0.5354, Val loss: 0.4809
# Epoch: 84, Train loss: 0.5018, Val loss: 0.4679
# Epoch: 86, Train loss: 0.5196, Val loss: 0.4386
# Epoch: 88, Train loss: 0.5050, Val loss: 0.4286
# Epoch: 90, Train loss: 0.4764, Val loss: 0.4258
# Epoch: 92, Train loss: 0.5096, Val loss: 0.4312
# Epoch: 94, Train loss: 0.5060, Val loss: 0.4296
# Epoch: 96, Train loss: 0.4878, Val loss: 0.4079
# Epoch: 98, Train loss: 0.4877, Val loss: 0.4124
# Epoch: 100, Train loss: 0.4600, Val loss: 0.3993
# Epoch: 102, Train loss: 0.4858, Val loss: 0.4029
# Epoch: 104, Train loss: 0.4572, Val loss: 0.3932
# Epoch: 106, Train loss: 0.5809, Val loss: 0.3902
# Epoch: 108, Train loss: 0.4578, Val loss: 0.4560
# Epoch: 110, Train loss: 0.4736, Val loss: 0.3927
# Epoch: 112, Train loss: 0.5262, Val loss: 0.3858
# Epoch: 114, Train loss: 0.4957, Val loss: 0.4210
# Epoch: 116, Train loss: 0.4868, Val loss: 0.4152
# Epoch: 118, Train loss: 0.4670, Val loss: 0.4026
# Epoch: 120, Train loss: 0.4347, Val loss: 0.3806
# Epoch: 122, Train loss: 0.4808, Val loss: 0.3746
# Epoch: 124, Train loss: 0.4341, Val loss: 0.4157
# Epoch: 126, Train loss: 0.4570, Val loss: 0.3955
# Epoch: 128, Train loss: 0.4524, Val loss: 0.3690
# Epoch: 130, Train loss: 0.4190, Val loss: 0.3754
# Epoch: 132, Train loss: 0.4625, Val loss: 0.4497
# Epoch: 134, Train loss: 0.4004, Val loss: 0.3554
# Epoch: 136, Train loss: 0.4025, Val loss: 0.3485
# Epoch: 138, Train loss: 0.4202, Val loss: 0.3467
# Epoch: 140, Train loss: 0.4316, Val loss: 0.3526
# Epoch: 142, Train loss: 0.4005, Val loss: 0.3442
# Epoch: 144, Train loss: 0.4173, Val loss: 0.3537
# Epoch: 146, Train loss: 0.4273, Val loss: 0.3970
# Epoch: 148, Train loss: 0.4013, Val loss: 0.3463
# Epoch: 150, Train loss: 0.4072, Val loss: 0.3458
# Epoch: 152, Train loss: 0.4146, Val loss: 0.3802
# Epoch: 154, Train loss: 0.4561, Val loss: 0.4310
# Epoch: 156, Train loss: 0.5012, Val loss: 0.5010
# Epoch: 158, Train loss: 0.4353, Val loss: 0.3521
# Epoch: 160, Train loss: 0.3955, Val loss: 0.3868
# Epoch: 162, Train loss: 0.4022, Val loss: 0.3406
# Epoch: 164, Train loss: 0.4063, Val loss: 0.3773
# Epoch: 166, Train loss: 0.4183, Val loss: 0.3391
# Epoch: 168, Train loss: 0.4035, Val loss: 0.3330
# Epoch: 170, Train loss: 0.4041, Val loss: 0.3400
# Epoch: 172, Train loss: 0.3799, Val loss: 0.3485
# Epoch: 174, Train loss: 0.3944, Val loss: 0.3384
# Epoch: 176, Train loss: 0.4060, Val loss: 0.3307
# Epoch: 178, Train loss: 0.3926, Val loss: 0.3383
# Epoch: 180, Train loss: 0.3858, Val loss: 0.3549
# Epoch: 182, Train loss: 0.3852, Val loss: 0.4675
# Epoch: 184, Train loss: 0.4166, Val loss: 0.3553
# Epoch: 186, Train loss: 0.3938, Val loss: 0.3281
# Epoch: 188, Train loss: 0.4088, Val loss: 0.3275
# Epoch: 190, Train loss: 0.3823, Val loss: 0.3280
# Epoch: 192, Train loss: 0.4051, Val loss: 0.3440
# Epoch: 194, Train loss: 0.3838, Val loss: 0.3349
# Epoch: 196, Train loss: 0.3717, Val loss: 0.3281
# Epoch: 198, Train loss: 0.4075, Val loss: 0.3356
# Epoch: 200, Train loss: 0.3697, Val loss: 0.3378
# Epoch: 202, Train loss: 0.3684, Val loss: 0.3238
# Epoch: 204, Train loss: 0.4118, Val loss: 0.3261
# Epoch: 206, Train loss: 0.3606, Val loss: 0.3235
# Epoch: 208, Train loss: 0.4026, Val loss: 0.3242
# Epoch: 210, Train loss: 0.3639, Val loss: 0.3250
# Epoch: 212, Train loss: 0.3689, Val loss: 0.3342
# Epoch: 214, Train loss: 0.4125, Val loss: 0.3378
# Epoch: 216, Train loss: 0.4178, Val loss: 0.4252
# Epoch: 218, Train loss: 0.4041, Val loss: 0.3241
# Epoch: 220, Train loss: 0.3636, Val loss: 0.3237
# Epoch: 222, Train loss: 0.3787, Val loss: 0.3233
# Epoch: 224, Train loss: 0.3564, Val loss: 0.3325
# Epoch: 226, Train loss: 0.3636, Val loss: 0.3210
# Epoch: 228, Train loss: 0.3794, Val loss: 0.3336
# Epoch: 230, Train loss: 0.3551, Val loss: 0.3311
# Epoch: 232, Train loss: 0.3511, Val loss: 0.3165
# Epoch: 234, Train loss: 0.3739, Val loss: 0.3163
# Epoch: 236, Train loss: 0.3685, Val loss: 0.3162
# Epoch: 238, Train loss: 0.3744, Val loss: 0.3224
# Epoch: 240, Train loss: 0.3794, Val loss: 0.3146
# Epoch: 242, Train loss: 0.3812, Val loss: 0.3169
# Epoch: 244, Train loss: 0.4049, Val loss: 0.3186
# Epoch: 246, Train loss: 0.3882, Val loss: 0.3994
# Epoch: 248, Train loss: 0.3814, Val loss: 0.3166
# Epoch: 250, Train loss: 0.3600, Val loss: 0.3143
# Epoch: 252, Train loss: 0.3835, Val loss: 0.3139
# Epoch: 254, Train loss: 0.3859, Val loss: 0.3307
# Epoch: 256, Train loss: 0.3781, Val loss: 0.3203
# Epoch: 258, Train loss: 0.3384, Val loss: 0.3251
# Epoch: 260, Train loss: 0.3783, Val loss: 0.3123
# Epoch: 262, Train loss: 0.3569, Val loss: 0.3112
# Epoch: 264, Train loss: 0.3558, Val loss: 0.3107
# Epoch: 266, Train loss: 0.3611, Val loss: 0.3117
# Epoch: 268, Train loss: 0.3641, Val loss: 0.3112
# Epoch: 270, Train loss: 0.3582, Val loss: 0.3331
# Epoch: 272, Train loss: 0.3658, Val loss: 0.3542
# Epoch: 274, Train loss: 0.3619, Val loss: 0.3491
# Epoch: 276, Train loss: 0.3611, Val loss: 0.3156
# Epoch: 278, Train loss: 0.4620, Val loss: 0.4522
# Epoch: 280, Train loss: 0.3599, Val loss: 0.3202
# Epoch: 282, Train loss: 0.3602, Val loss: 0.3119
# Epoch: 284, Train loss: 0.3491, Val loss: 0.3214
# Epoch: 286, Train loss: 0.3416, Val loss: 0.3250
# Epoch: 288, Train loss: 0.3975, Val loss: 0.3185
# Epoch: 290, Train loss: 0.3826, Val loss: 0.3635
# Epoch: 292, Train loss: 0.3804, Val loss: 0.3897
# Epoch: 294, Train loss: 0.3904, Val loss: 0.3139
# Epoch: 296, Train loss: 0.3445, Val loss: 0.3110
# Epoch: 298, Train loss: 0.3505, Val loss: 0.3117
# Epoch: 300, Train loss: 0.3530, Val loss: 0.3085
# Epoch: 302, Train loss: 0.3629, Val loss: 0.3067
# Epoch: 304, Train loss: 0.3467, Val loss: 0.3016
# Epoch: 306, Train loss: 0.3537, Val loss: 0.3186
# Epoch: 308, Train loss: 0.3544, Val loss: 0.3068
# Epoch: 310, Train loss: 0.3521, Val loss: 0.3183
# Epoch: 312, Train loss: 0.3221, Val loss: 0.3086
# Epoch: 314, Train loss: 0.3333, Val loss: 0.3240
# Epoch: 316, Train loss: 0.3464, Val loss: 0.3025
# Epoch: 318, Train loss: 0.3399, Val loss: 0.2984
# Epoch: 320, Train loss: 0.3856, Val loss: 0.3570
# Epoch: 322, Train loss: 0.3658, Val loss: 0.2974
# Epoch: 324, Train loss: 0.3480, Val loss: 0.2963
# Epoch: 326, Train loss: 0.3138, Val loss: 0.2968
# Epoch: 328, Train loss: 0.3276, Val loss: 0.3165
# Epoch: 330, Train loss: 0.3415, Val loss: 0.2989
# Epoch: 332, Train loss: 0.3548, Val loss: 0.3167
# Epoch: 334, Train loss: 0.3463, Val loss: 0.2960
# Epoch: 336, Train loss: 0.3641, Val loss: 0.3512
# Epoch: 338, Train loss: 0.3906, Val loss: 0.3010
# Epoch: 340, Train loss: 0.3561, Val loss: 0.3057
# Epoch: 342, Train loss: 0.3211, Val loss: 0.3092
# Epoch: 344, Train loss: 0.3346, Val loss: 0.3280
# Epoch: 346, Train loss: 0.3560, Val loss: 0.3300
# Epoch: 348, Train loss: 0.3436, Val loss: 0.2954
# Epoch: 350, Train loss: 0.3419, Val loss: 0.3137
# Epoch: 352, Train loss: 0.3661, Val loss: 0.3547
# Epoch: 354, Train loss: 0.3921, Val loss: 0.3033
# Epoch: 356, Train loss: 0.3344, Val loss: 0.2959
# Epoch: 358, Train loss: 0.3493, Val loss: 0.3018
# Epoch: 360, Train loss: 0.3665, Val loss: 0.2976
# Epoch: 362, Train loss: 0.3442, Val loss: 0.3345
# Epoch: 364, Train loss: 0.3332, Val loss: 0.2920
# Epoch: 366, Train loss: 0.3209, Val loss: 0.3036
# Epoch: 368, Train loss: 0.3657, Val loss: 0.2986
# Epoch: 370, Train loss: 0.3149, Val loss: 0.2868
# Epoch: 372, Train loss: 0.3187, Val loss: 0.2861
# Epoch: 374, Train loss: 0.3348, Val loss: 0.3165
# Epoch: 376, Train loss: 0.3505, Val loss: 0.3293
# Epoch: 378, Train loss: 0.3578, Val loss: 0.3009
# Epoch: 380, Train loss: 0.3574, Val loss: 0.2887
# Epoch: 382, Train loss: 0.3692, Val loss: 0.2980
# Epoch: 384, Train loss: 0.3439, Val loss: 0.2955
# Epoch: 386, Train loss: 0.3352, Val loss: 0.2998
# Epoch: 388, Train loss: 0.3411, Val loss: 0.3146
# Epoch: 390, Train loss: 0.3381, Val loss: 0.3101
# Epoch: 392, Train loss: 0.3231, Val loss: 0.3104
# Epoch: 394, Train loss: 0.3339, Val loss: 0.2782
# Epoch: 396, Train loss: 0.3434, Val loss: 0.3057
# Epoch: 398, Train loss: 0.2967, Val loss: 0.2919
# Epoch: 400, Train loss: 0.3258, Val loss: 0.2835
# Epoch: 402, Train loss: 0.3103, Val loss: 0.2804
# Epoch: 404, Train loss: 0.3190, Val loss: 0.2882
# Epoch: 406, Train loss: 0.3248, Val loss: 0.2793
# Epoch: 408, Train loss: 0.3078, Val loss: 0.2810
# Epoch: 410, Train loss: 0.3155, Val loss: 0.2895
# Epoch: 412, Train loss: 0.3163, Val loss: 0.3001
# Epoch: 414, Train loss: 0.3387, Val loss: 0.3461
# Epoch: 416, Train loss: 0.3338, Val loss: 0.2873
# Epoch: 418, Train loss: 0.2892, Val loss: 0.2802
# Epoch: 420, Train loss: 0.3268, Val loss: 0.2757
# Epoch: 422, Train loss: 0.2936, Val loss: 0.2983
# Epoch: 424, Train loss: 0.3125, Val loss: 0.2700
# Epoch: 426, Train loss: 0.3289, Val loss: 0.2657
# Epoch: 428, Train loss: 0.3016, Val loss: 0.2690
# Epoch: 430, Train loss: 0.3083, Val loss: 0.2874
# Epoch: 432, Train loss: 0.3048, Val loss: 0.2658
# Epoch: 434, Train loss: 0.2883, Val loss: 0.2856
# Epoch: 436, Train loss: 0.3063, Val loss: 0.2602
# Epoch: 438, Train loss: 0.3014, Val loss: 0.2771
# Epoch: 440, Train loss: 0.3285, Val loss: 0.3058
# Epoch: 442, Train loss: 0.3322, Val loss: 0.2661
# Epoch: 444, Train loss: 0.3088, Val loss: 0.2752
# Epoch: 446, Train loss: 0.3426, Val loss: 0.2689
# Epoch: 448, Train loss: 0.2963, Val loss: 0.2626
# Epoch: 450, Train loss: 0.2790, Val loss: 0.2766
# Epoch: 452, Train loss: 0.3172, Val loss: 0.2483
# Epoch: 454, Train loss: 0.3073, Val loss: 0.2606
# Epoch: 456, Train loss: 0.2836, Val loss: 0.2636
# Epoch: 458, Train loss: 0.3096, Val loss: 0.2644
# Epoch: 460, Train loss: 0.3084, Val loss: 0.2600
# Epoch: 462, Train loss: 0.3077, Val loss: 0.2819
# Epoch: 464, Train loss: 0.2954, Val loss: 0.2485
# Epoch: 466, Train loss: 0.2974, Val loss: 0.2552
# Epoch: 468, Train loss: 0.2845, Val loss: 0.2709
# Epoch: 470, Train loss: 0.3019, Val loss: 0.2499
# Epoch: 472, Train loss: 0.2845, Val loss: 0.2619
# Epoch: 474, Train loss: 0.2867, Val loss: 0.2678
# Epoch: 476, Train loss: 0.2851, Val loss: 0.2525
# Epoch: 478, Train loss: 0.3088, Val loss: 0.2822
# Epoch: 480, Train loss: 0.3180, Val loss: 0.2401
# Epoch: 482, Train loss: 0.2726, Val loss: 0.2550
# Epoch: 484, Train loss: 0.2739, Val loss: 0.2504
# Epoch: 486, Train loss: 0.2942, Val loss: 0.2568
# Epoch: 488, Train loss: 0.2842, Val loss: 0.2400
# Epoch: 490, Train loss: 0.3040, Val loss: 0.2794
# Epoch: 492, Train loss: 0.2829, Val loss: 0.2431
# Epoch: 494, Train loss: 0.2820, Val loss: 0.2547
# Epoch: 496, Train loss: 0.2857, Val loss: 0.2456
# Epoch: 498, Train loss: 0.2734, Val loss: 0.2311
# Validation MSE: 0.2287, MAE: 0.3477

# %%
plot_loss(anion_gat_train_loss_25, anion_gat_val_loss_25)

# %%
plot_loss(cation_gat_train_loss_25, cation_gat_val_loss_25)

# %%
plot_targets(anion_gat_val_pred_25, anion_gat_val_true_25, anion_gat_mse_25, anion_gat_mae_25, save_path="anion_GAT_val_25.png")

# %%
plot_targets(cation_gat_val_pred_25, cation_gat_val_true_25, cation_gat_mse_25, cation_gat_mae_25, save_path="cation_GAT_val_25.png")

# %% [markdown]
# # 50% train dataset

# %%
# Load the anion training set
anion_50_load_train_dataset_path = 'dataset/train_anion_data_list_50.pt' # Training set
anion_50_loaded_train_data_list = load_data_list(anion_50_load_train_dataset_path)
anion_50_train_loader = DataLoader(anion_50_loaded_train_data_list, batch_size=128, shuffle=True)  

# Load the cation training set
cation_50_load_train_dataset_path = 'dataset/train_cation_data_list_50.pt' # Training set
cation_50_loaded_train_data_list = load_data_list(cation_50_load_train_dataset_path)
cation_50_train_loader = DataLoader(cation_50_loaded_train_data_list, batch_size=128, shuffle=True)

# %%
# Train the GCN model with the number of epochs set to 100
epochs = 500

# Initialize the GCN model with hidden layer dimension set to 256
model_anion_50 = GAT(in_channels=5, hidden_channels=256).to(device)  # Move the model to GPU
model_cation_50 = GAT(in_channels=5, hidden_channels=256).to(device)  # Move the model to GPU

# %%
anion_gat_train_loss_50, anion_gat_val_loss_50, anion_gat_train_pred_50, anion_gat_train_true_50, anion_gat_val_pred_50, anion_gat_val_true_50, anion_gat_mse_50, anion_gat_mae_50 = train_epochs(
    11, epochs,model_anion_50, anion_50_train_loader, anion_val_loader, "Anion_GAT_model_HOMO_50.pt"
)
# Out:
# Epoch: 0, Train loss: 2.2448, Val loss: 1.5722
# Epoch: 2, Train loss: 1.2421, Val loss: 0.9200
# Epoch: 4, Train loss: 1.0624, Val loss: 0.8203
# Epoch: 6, Train loss: 0.9934, Val loss: 0.8002
# Epoch: 8, Train loss: 0.9123, Val loss: 0.7235
# Epoch: 10, Train loss: 0.8587, Val loss: 0.7344
# Epoch: 12, Train loss: 0.8561, Val loss: 0.7060
# Epoch: 14, Train loss: 0.8348, Val loss: 0.6954
# Epoch: 16, Train loss: 0.8343, Val loss: 0.6904
# Epoch: 18, Train loss: 0.8489, Val loss: 0.7093
# Epoch: 20, Train loss: 0.8303, Val loss: 0.6846
# Epoch: 22, Train loss: 0.8263, Val loss: 0.6819
# Epoch: 24, Train loss: 0.8342, Val loss: 0.7467
# Epoch: 26, Train loss: 0.8767, Val loss: 0.6755
# Epoch: 28, Train loss: 0.7932, Val loss: 0.6767
# Epoch: 30, Train loss: 0.8164, Val loss: 0.6716
# Epoch: 32, Train loss: 0.7800, Val loss: 0.6686
# Epoch: 34, Train loss: 0.7762, Val loss: 0.6739
# Epoch: 36, Train loss: 0.7864, Val loss: 0.6589
# Epoch: 38, Train loss: 0.7752, Val loss: 0.6725
# Epoch: 40, Train loss: 0.7802, Val loss: 0.6607
# Epoch: 42, Train loss: 0.7904, Val loss: 0.6482
# Epoch: 44, Train loss: 0.7554, Val loss: 0.6650
# Epoch: 46, Train loss: 0.7875, Val loss: 0.6389
# Epoch: 48, Train loss: 0.7594, Val loss: 0.6918
# Epoch: 50, Train loss: 0.7309, Val loss: 0.6371
# Epoch: 52, Train loss: 0.7466, Val loss: 0.7321
# Epoch: 54, Train loss: 0.7437, Val loss: 0.6231
# Epoch: 56, Train loss: 0.7341, Val loss: 0.6292
# Epoch: 58, Train loss: 0.7268, Val loss: 0.6190
# Epoch: 60, Train loss: 0.7297, Val loss: 0.6169
# Epoch: 62, Train loss: 0.7040, Val loss: 0.6464
# Epoch: 64, Train loss: 0.7201, Val loss: 0.6058
# Epoch: 66, Train loss: 0.7178, Val loss: 0.6091
# Epoch: 68, Train loss: 0.7089, Val loss: 0.6717
# Epoch: 70, Train loss: 0.7594, Val loss: 0.6869
# Epoch: 72, Train loss: 0.7653, Val loss: 0.5947
# Epoch: 74, Train loss: 0.6987, Val loss: 0.6308
# Epoch: 76, Train loss: 0.7072, Val loss: 0.6139
# Epoch: 78, Train loss: 0.6935, Val loss: 0.6062
# Epoch: 80, Train loss: 0.6887, Val loss: 0.5993
# Epoch: 82, Train loss: 0.7068, Val loss: 0.5869
# Epoch: 84, Train loss: 0.6888, Val loss: 0.5885
# Epoch: 86, Train loss: 0.6881, Val loss: 0.6006
# Epoch: 88, Train loss: 0.6885, Val loss: 0.5703
# Epoch: 90, Train loss: 0.6773, Val loss: 0.5746
# Epoch: 92, Train loss: 0.6513, Val loss: 0.6179
# Epoch: 94, Train loss: 0.6494, Val loss: 0.6154
# Epoch: 96, Train loss: 0.6315, Val loss: 0.5751
# Epoch: 98, Train loss: 0.6583, Val loss: 0.5884
# Epoch: 100, Train loss: 0.6490, Val loss: 0.5799
# Epoch: 102, Train loss: 0.7183, Val loss: 0.5451
# Epoch: 104, Train loss: 0.6351, Val loss: 0.5727
# Epoch: 106, Train loss: 0.6451, Val loss: 0.5934
# Epoch: 108, Train loss: 0.6689, Val loss: 0.6178
# Epoch: 110, Train loss: 0.6782, Val loss: 0.6266
# Epoch: 112, Train loss: 0.6291, Val loss: 0.5465
# Epoch: 114, Train loss: 0.6353, Val loss: 0.5404
# Epoch: 116, Train loss: 0.6337, Val loss: 0.5815
# Epoch: 118, Train loss: 0.6810, Val loss: 0.5884
# Epoch: 120, Train loss: 0.6713, Val loss: 0.6167
# Epoch: 122, Train loss: 0.6951, Val loss: 0.5619
# Epoch: 124, Train loss: 0.6281, Val loss: 0.5098
# Epoch: 126, Train loss: 0.5992, Val loss: 0.5923
# Epoch: 128, Train loss: 0.5858, Val loss: 0.5083
# Epoch: 130, Train loss: 0.5834, Val loss: 0.5262
# Epoch: 132, Train loss: 0.5663, Val loss: 0.5098
# Epoch: 134, Train loss: 0.6054, Val loss: 0.4960
# Epoch: 136, Train loss: 0.5970, Val loss: 0.4993
# Epoch: 138, Train loss: 0.5660, Val loss: 0.4950
# Epoch: 140, Train loss: 0.6393, Val loss: 0.5419
# Epoch: 142, Train loss: 0.5632, Val loss: 0.4937
# Epoch: 144, Train loss: 0.5535, Val loss: 0.5084
# Epoch: 146, Train loss: 0.5371, Val loss: 0.4602
# Epoch: 148, Train loss: 0.5793, Val loss: 0.4702
# Epoch: 150, Train loss: 0.5381, Val loss: 0.4513
# Epoch: 152, Train loss: 0.5164, Val loss: 0.4421
# Epoch: 154, Train loss: 0.5084, Val loss: 0.4557
# Epoch: 156, Train loss: 0.5192, Val loss: 0.4412
# Epoch: 158, Train loss: 0.4846, Val loss: 0.4303
# Epoch: 160, Train loss: 0.5789, Val loss: 0.4448
# Epoch: 162, Train loss: 0.5163, Val loss: 0.5614
# Epoch: 164, Train loss: 0.6497, Val loss: 0.4641
# Epoch: 166, Train loss: 0.6533, Val loss: 0.5188
# Epoch: 168, Train loss: 0.5880, Val loss: 0.4925
# Epoch: 170, Train loss: 0.5673, Val loss: 0.4967
# Epoch: 172, Train loss: 0.5113, Val loss: 0.4361
# Epoch: 174, Train loss: 0.5014, Val loss: 0.4359
# Epoch: 176, Train loss: 0.4806, Val loss: 0.4578
# Epoch: 178, Train loss: 0.5155, Val loss: 0.5591
# Epoch: 180, Train loss: 0.4830, Val loss: 0.4744
# Epoch: 182, Train loss: 0.4884, Val loss: 0.4261
# Epoch: 184, Train loss: 0.4699, Val loss: 0.4247
# Epoch: 186, Train loss: 0.4438, Val loss: 0.4359
# Epoch: 188, Train loss: 0.4512, Val loss: 0.4151
# Epoch: 190, Train loss: 0.4320, Val loss: 0.4231
# Epoch: 192, Train loss: 0.4627, Val loss: 0.4335
# Epoch: 194, Train loss: 0.4521, Val loss: 0.4494
# Epoch: 196, Train loss: 0.4886, Val loss: 0.4552
# Epoch: 198, Train loss: 0.4595, Val loss: 0.4451
# Epoch: 200, Train loss: 0.4579, Val loss: 0.4092
# Epoch: 202, Train loss: 0.4086, Val loss: 0.3971
# Epoch: 204, Train loss: 0.4323, Val loss: 0.4026
# Epoch: 206, Train loss: 0.4157, Val loss: 0.4534
# Epoch: 208, Train loss: 0.4258, Val loss: 0.3956
# Epoch: 210, Train loss: 0.4108, Val loss: 0.3891
# Epoch: 212, Train loss: 0.4238, Val loss: 0.4078
# Epoch: 214, Train loss: 0.4140, Val loss: 0.3912
# Epoch: 216, Train loss: 0.4199, Val loss: 0.3851
# Epoch: 218, Train loss: 0.4490, Val loss: 0.4020
# Epoch: 220, Train loss: 0.4090, Val loss: 0.4057
# Epoch: 222, Train loss: 0.4261, Val loss: 0.3804
# Epoch: 224, Train loss: 0.4114, Val loss: 0.3884
# Epoch: 226, Train loss: 0.4036, Val loss: 0.4448
# Epoch: 228, Train loss: 0.4336, Val loss: 0.3855
# Epoch: 230, Train loss: 0.4185, Val loss: 0.3812
# Epoch: 232, Train loss: 0.4089, Val loss: 0.3888
# Epoch: 234, Train loss: 0.3773, Val loss: 0.3813
# Epoch: 236, Train loss: 0.3968, Val loss: 0.3858
# Epoch: 238, Train loss: 0.3967, Val loss: 0.3767
# Epoch: 240, Train loss: 0.4002, Val loss: 0.3795
# Epoch: 242, Train loss: 0.3838, Val loss: 0.3753
# Epoch: 244, Train loss: 0.3995, Val loss: 0.3768
# Epoch: 246, Train loss: 0.3791, Val loss: 0.3746
# Epoch: 248, Train loss: 0.4270, Val loss: 0.4217
# Epoch: 250, Train loss: 0.3992, Val loss: 0.3835
# Epoch: 252, Train loss: 0.4036, Val loss: 0.3754
# Epoch: 254, Train loss: 0.3783, Val loss: 0.3732
# Epoch: 256, Train loss: 0.3928, Val loss: 0.3819
# Epoch: 258, Train loss: 0.3896, Val loss: 0.3815
# Epoch: 260, Train loss: 0.3929, Val loss: 0.3686
# Epoch: 262, Train loss: 0.3825, Val loss: 0.3879
# Epoch: 264, Train loss: 0.4265, Val loss: 0.3681
# Epoch: 266, Train loss: 0.4147, Val loss: 0.3703
# Epoch: 268, Train loss: 0.3786, Val loss: 0.3587
# Epoch: 270, Train loss: 0.3983, Val loss: 0.3797
# Epoch: 272, Train loss: 0.3920, Val loss: 0.3631
# Epoch: 274, Train loss: 0.3839, Val loss: 0.3776
# Epoch: 276, Train loss: 0.3781, Val loss: 0.3668
# Epoch: 278, Train loss: 0.3839, Val loss: 0.3582
# Epoch: 280, Train loss: 0.3863, Val loss: 0.4075
# Epoch: 282, Train loss: 0.3699, Val loss: 0.3630
# Epoch: 284, Train loss: 0.3661, Val loss: 0.3469
# Epoch: 286, Train loss: 0.3622, Val loss: 0.3603
# Epoch: 288, Train loss: 0.3788, Val loss: 0.3627
# Epoch: 290, Train loss: 0.4237, Val loss: 0.4192
# Epoch: 292, Train loss: 0.3865, Val loss: 0.3893
# Epoch: 294, Train loss: 0.3712, Val loss: 0.3555
# Epoch: 296, Train loss: 0.3590, Val loss: 0.3583
# Epoch: 298, Train loss: 0.3624, Val loss: 0.3616
# Epoch: 300, Train loss: 0.3548, Val loss: 0.3477
# Epoch: 302, Train loss: 0.3438, Val loss: 0.3352
# Epoch: 304, Train loss: 0.3915, Val loss: 0.3729
# Epoch: 306, Train loss: 0.4016, Val loss: 0.3508
# Epoch: 308, Train loss: 0.3467, Val loss: 0.3467
# Epoch: 310, Train loss: 0.3501, Val loss: 0.3509
# Epoch: 312, Train loss: 0.3450, Val loss: 0.3419
# Epoch: 314, Train loss: 0.3288, Val loss: 0.3338
# Epoch: 316, Train loss: 0.3419, Val loss: 0.3372
# Epoch: 318, Train loss: 0.3574, Val loss: 0.3585
# Epoch: 320, Train loss: 0.3347, Val loss: 0.3319
# Epoch: 322, Train loss: 0.3439, Val loss: 0.3363
# Epoch: 324, Train loss: 0.3603, Val loss: 0.3298
# Epoch: 326, Train loss: 0.3445, Val loss: 0.3259
# Epoch: 328, Train loss: 0.3380, Val loss: 0.3278
# Epoch: 330, Train loss: 0.3553, Val loss: 0.3632
# Epoch: 332, Train loss: 0.3625, Val loss: 0.3471
# Epoch: 334, Train loss: 0.3534, Val loss: 0.3940
# Epoch: 336, Train loss: 0.3620, Val loss: 0.3473
# Epoch: 338, Train loss: 0.3574, Val loss: 0.3375
# Epoch: 340, Train loss: 0.3534, Val loss: 0.3802
# Epoch: 342, Train loss: 0.3480, Val loss: 0.3455
# Epoch: 344, Train loss: 0.3276, Val loss: 0.3192
# Epoch: 346, Train loss: 0.3282, Val loss: 0.3222
# Epoch: 348, Train loss: 0.3451, Val loss: 0.3215
# Epoch: 350, Train loss: 0.3225, Val loss: 0.3298
# Epoch: 352, Train loss: 0.3407, Val loss: 0.3185
# Epoch: 354, Train loss: 0.3229, Val loss: 0.3156
# Epoch: 356, Train loss: 0.3197, Val loss: 0.3146
# Epoch: 358, Train loss: 0.3296, Val loss: 0.3181
# Epoch: 360, Train loss: 0.3350, Val loss: 0.3616
# Epoch: 362, Train loss: 0.3433, Val loss: 0.3813
# Epoch: 364, Train loss: 0.3320, Val loss: 0.3277
# Epoch: 366, Train loss: 0.3444, Val loss: 0.3142
# Epoch: 368, Train loss: 0.3336, Val loss: 0.3314
# Epoch: 370, Train loss: 0.3326, Val loss: 0.3336
# Epoch: 372, Train loss: 0.3163, Val loss: 0.3056
# Epoch: 374, Train loss: 0.3211, Val loss: 0.3131
# Epoch: 376, Train loss: 0.3343, Val loss: 0.3125
# Epoch: 378, Train loss: 0.3099, Val loss: 0.2942
# Epoch: 380, Train loss: 0.3087, Val loss: 0.3033
# Epoch: 382, Train loss: 0.3037, Val loss: 0.2929
# Epoch: 384, Train loss: 0.3289, Val loss: 0.3185
# Epoch: 386, Train loss: 0.3250, Val loss: 0.3125
# Epoch: 388, Train loss: 0.3238, Val loss: 0.3258
# Epoch: 390, Train loss: 0.3049, Val loss: 0.3249
# Epoch: 392, Train loss: 0.3395, Val loss: 0.3518
# Epoch: 394, Train loss: 0.3104, Val loss: 0.3008
# Epoch: 396, Train loss: 0.3072, Val loss: 0.2938
# Epoch: 398, Train loss: 0.2978, Val loss: 0.2936
# Epoch: 400, Train loss: 0.3063, Val loss: 0.2822
# Epoch: 402, Train loss: 0.3274, Val loss: 0.2890
# Epoch: 404, Train loss: 0.3253, Val loss: 0.3084
# Epoch: 406, Train loss: 0.3487, Val loss: 0.3098
# Epoch: 408, Train loss: 0.3214, Val loss: 0.2858
# Epoch: 410, Train loss: 0.2953, Val loss: 0.2850
# Epoch: 412, Train loss: 0.2982, Val loss: 0.2831
# Epoch: 414, Train loss: 0.3448, Val loss: 0.2978
# Epoch: 416, Train loss: 0.3108, Val loss: 0.2961
# Epoch: 418, Train loss: 0.2814, Val loss: 0.2819
# Epoch: 420, Train loss: 0.2961, Val loss: 0.2961
# Epoch: 422, Train loss: 0.2875, Val loss: 0.2773
# Epoch: 424, Train loss: 0.3162, Val loss: 0.2929
# Epoch: 426, Train loss: 0.3587, Val loss: 0.3468
# Epoch: 428, Train loss: 0.2984, Val loss: 0.2719
# Epoch: 430, Train loss: 0.3124, Val loss: 0.2767
# Epoch: 432, Train loss: 0.2980, Val loss: 0.2955
# Epoch: 434, Train loss: 0.3105, Val loss: 0.3440
# Epoch: 436, Train loss: 0.3395, Val loss: 0.2803
# Epoch: 438, Train loss: 0.3135, Val loss: 0.2945
# Epoch: 440, Train loss: 0.2855, Val loss: 0.2698
# Epoch: 442, Train loss: 0.3246, Val loss: 0.3282
# Epoch: 444, Train loss: 0.2934, Val loss: 0.2715
# Epoch: 446, Train loss: 0.3320, Val loss: 0.3015
# Epoch: 448, Train loss: 0.3258, Val loss: 0.2821
# Epoch: 450, Train loss: 0.2748, Val loss: 0.2746
# Epoch: 452, Train loss: 0.2717, Val loss: 0.2627
# Epoch: 454, Train loss: 0.2878, Val loss: 0.2996
# Epoch: 456, Train loss: 0.2767, Val loss: 0.2972
# Epoch: 458, Train loss: 0.2782, Val loss: 0.2665
# Epoch: 460, Train loss: 0.2898, Val loss: 0.2651
# Epoch: 462, Train loss: 0.2779, Val loss: 0.2689
# Epoch: 464, Train loss: 0.2514, Val loss: 0.2590
# Epoch: 466, Train loss: 0.2687, Val loss: 0.2536
# Epoch: 468, Train loss: 0.2491, Val loss: 0.2564
# Epoch: 470, Train loss: 0.2676, Val loss: 0.2516
# Epoch: 472, Train loss: 0.2922, Val loss: 0.2544
# Epoch: 474, Train loss: 0.2875, Val loss: 0.2705
# Epoch: 476, Train loss: 0.2867, Val loss: 0.2564
# Epoch: 478, Train loss: 0.2744, Val loss: 0.2479
# Epoch: 480, Train loss: 0.2385, Val loss: 0.2460
# Epoch: 482, Train loss: 0.2961, Val loss: 0.2846
# Epoch: 484, Train loss: 0.2855, Val loss: 0.2650
# Epoch: 486, Train loss: 0.2981, Val loss: 0.2673
# Epoch: 488, Train loss: 0.2907, Val loss: 0.2729
# Epoch: 490, Train loss: 0.2704, Val loss: 0.2563
# Epoch: 492, Train loss: 0.2655, Val loss: 0.2487
# Epoch: 494, Train loss: 0.2998, Val loss: 0.2807
# Epoch: 496, Train loss: 0.2661, Val loss: 0.3210
# Epoch: 498, Train loss: 0.2982, Val loss: 0.2709
# Validation MSE: 0.2416, MAE: 0.3778

# %%
cation_gat_train_loss_50, cation_gat_val_loss_50, cation_gat_train_pred_50, cation_gat_train_true_50, cation_gat_val_pred_50, cation_gat_val_true_50, cation_gat_mse_50, cation_gat_mae_50 = train_epochs(
    12, epochs,model_cation_50, cation_50_train_loader, cation_val_loader, "Cation_GAT_model_LUMO_50.pt"
)
# Out:
# Epoch: 0, Train loss: 5.6730, Val loss: 2.9277
# Epoch: 2, Train loss: 1.7716, Val loss: 1.5194
# Epoch: 4, Train loss: 1.4321, Val loss: 1.1262
# Epoch: 6, Train loss: 0.9728, Val loss: 0.7512
# Epoch: 8, Train loss: 0.8589, Val loss: 0.6869
# Epoch: 10, Train loss: 0.8047, Val loss: 0.6651
# Epoch: 12, Train loss: 0.8102, Val loss: 0.6339
# Epoch: 14, Train loss: 0.7523, Val loss: 0.6239
# Epoch: 16, Train loss: 0.7056, Val loss: 0.6348
# Epoch: 18, Train loss: 0.7172, Val loss: 0.6307
# Epoch: 20, Train loss: 0.7292, Val loss: 0.5655
# Epoch: 22, Train loss: 0.6824, Val loss: 0.5428
# Epoch: 24, Train loss: 0.6440, Val loss: 0.5403
# Epoch: 26, Train loss: 0.6296, Val loss: 0.5203
# Epoch: 28, Train loss: 0.6287, Val loss: 0.5145
# Epoch: 30, Train loss: 0.6308, Val loss: 0.5068
# Epoch: 32, Train loss: 0.6181, Val loss: 0.5658
# Epoch: 34, Train loss: 0.6274, Val loss: 0.5174
# Epoch: 36, Train loss: 0.6182, Val loss: 0.5159
# Epoch: 38, Train loss: 0.6013, Val loss: 0.5232
# Epoch: 40, Train loss: 0.5616, Val loss: 0.4594
# Epoch: 42, Train loss: 0.5536, Val loss: 0.4746
# Epoch: 44, Train loss: 0.5779, Val loss: 0.4448
# Epoch: 46, Train loss: 0.5433, Val loss: 0.4304
# Epoch: 48, Train loss: 0.5476, Val loss: 0.5946
# Epoch: 50, Train loss: 0.5039, Val loss: 0.4483
# Epoch: 52, Train loss: 0.5174, Val loss: 0.4261
# Epoch: 54, Train loss: 0.5069, Val loss: 0.4026
# Epoch: 56, Train loss: 0.5152, Val loss: 0.3992
# Epoch: 58, Train loss: 0.4965, Val loss: 0.3906
# Epoch: 60, Train loss: 0.5135, Val loss: 0.4102
# Epoch: 62, Train loss: 0.4832, Val loss: 0.3853
# Epoch: 64, Train loss: 0.4792, Val loss: 0.3816
# Epoch: 66, Train loss: 0.5017, Val loss: 0.4176
# Epoch: 68, Train loss: 0.4752, Val loss: 0.3848
# Epoch: 70, Train loss: 0.4701, Val loss: 0.4998
# Epoch: 72, Train loss: 0.4860, Val loss: 0.3615
# Epoch: 74, Train loss: 0.4411, Val loss: 0.3544
# Epoch: 76, Train loss: 0.4536, Val loss: 0.3512
# Epoch: 78, Train loss: 0.4536, Val loss: 0.3683
# Epoch: 80, Train loss: 0.4760, Val loss: 0.3494
# Epoch: 82, Train loss: 0.4437, Val loss: 0.3758
# Epoch: 84, Train loss: 0.4417, Val loss: 0.3393
# Epoch: 86, Train loss: 0.4323, Val loss: 0.3427
# Epoch: 88, Train loss: 0.4512, Val loss: 0.3338
# Epoch: 90, Train loss: 0.4023, Val loss: 0.3622
# Epoch: 92, Train loss: 0.4437, Val loss: 0.3896
# Epoch: 94, Train loss: 0.4191, Val loss: 0.3446
# Epoch: 96, Train loss: 0.4498, Val loss: 0.4480
# Epoch: 98, Train loss: 0.4535, Val loss: 0.3628
# Epoch: 100, Train loss: 0.4153, Val loss: 0.3217
# Epoch: 102, Train loss: 0.4192, Val loss: 0.3340
# Epoch: 104, Train loss: 0.4226, Val loss: 0.3230
# Epoch: 106, Train loss: 0.3928, Val loss: 0.3226
# Epoch: 108, Train loss: 0.4421, Val loss: 0.3125
# Epoch: 110, Train loss: 0.4170, Val loss: 0.3410
# Epoch: 112, Train loss: 0.4259, Val loss: 0.4023
# Epoch: 114, Train loss: 0.4242, Val loss: 0.3119
# Epoch: 116, Train loss: 0.4456, Val loss: 0.3116
# Epoch: 118, Train loss: 0.3996, Val loss: 0.3161
# Epoch: 120, Train loss: 0.3898, Val loss: 0.3143
# Epoch: 122, Train loss: 0.4135, Val loss: 0.3121
# Epoch: 124, Train loss: 0.4061, Val loss: 0.3134
# Epoch: 126, Train loss: 0.4208, Val loss: 0.3171
# Epoch: 128, Train loss: 0.4051, Val loss: 0.3108
# Epoch: 130, Train loss: 0.3764, Val loss: 0.3136
# Epoch: 132, Train loss: 0.3925, Val loss: 0.3132
# Epoch: 134, Train loss: 0.4000, Val loss: 0.3057
# Epoch: 136, Train loss: 0.3888, Val loss: 0.3087
# Epoch: 138, Train loss: 0.3955, Val loss: 0.3076
# Epoch: 140, Train loss: 0.4074, Val loss: 0.3163
# Epoch: 142, Train loss: 0.4002, Val loss: 0.3105
# Epoch: 144, Train loss: 0.3983, Val loss: 0.3239
# Epoch: 146, Train loss: 0.3762, Val loss: 0.3066
# Epoch: 148, Train loss: 0.4010, Val loss: 0.3218
# Epoch: 150, Train loss: 0.3807, Val loss: 0.3305
# Epoch: 152, Train loss: 0.3939, Val loss: 0.3198
# Epoch: 154, Train loss: 0.3782, Val loss: 0.3001
# Epoch: 156, Train loss: 0.3854, Val loss: 0.3225
# Epoch: 158, Train loss: 0.3991, Val loss: 0.3112
# Epoch: 160, Train loss: 0.3824, Val loss: 0.3053
# Epoch: 162, Train loss: 0.4072, Val loss: 0.3492
# Epoch: 164, Train loss: 0.4278, Val loss: 0.3126
# Epoch: 166, Train loss: 0.3893, Val loss: 0.2996
# Epoch: 168, Train loss: 0.3748, Val loss: 0.3015
# Epoch: 170, Train loss: 0.3753, Val loss: 0.2954
# Epoch: 172, Train loss: 0.3952, Val loss: 0.2954
# Epoch: 174, Train loss: 0.3920, Val loss: 0.3095
# Epoch: 176, Train loss: 0.4123, Val loss: 0.2992
# Epoch: 178, Train loss: 0.3898, Val loss: 0.3037
# Epoch: 180, Train loss: 0.3716, Val loss: 0.2971
# Epoch: 182, Train loss: 0.3891, Val loss: 0.3189
# Epoch: 184, Train loss: 0.3693, Val loss: 0.3045
# Epoch: 186, Train loss: 0.3987, Val loss: 0.3060
# Epoch: 188, Train loss: 0.3626, Val loss: 0.3071
# Epoch: 190, Train loss: 0.3920, Val loss: 0.3338
# Epoch: 192, Train loss: 0.3938, Val loss: 0.3010
# Epoch: 194, Train loss: 0.3768, Val loss: 0.2925
# Epoch: 196, Train loss: 0.3608, Val loss: 0.2925
# Epoch: 198, Train loss: 0.3688, Val loss: 0.3413
# Epoch: 200, Train loss: 0.3952, Val loss: 0.3096
# Epoch: 202, Train loss: 0.3652, Val loss: 0.2903
# Epoch: 204, Train loss: 0.3758, Val loss: 0.2916
# Epoch: 206, Train loss: 0.3842, Val loss: 0.2928
# Epoch: 208, Train loss: 0.3764, Val loss: 0.2918
# Epoch: 210, Train loss: 0.3944, Val loss: 0.3058
# Epoch: 212, Train loss: 0.3707, Val loss: 0.2909
# Epoch: 214, Train loss: 0.3726, Val loss: 0.3152
# Epoch: 216, Train loss: 0.4079, Val loss: 0.3035
# Epoch: 218, Train loss: 0.3805, Val loss: 0.2886
# Epoch: 220, Train loss: 0.3672, Val loss: 0.2912
# Epoch: 222, Train loss: 0.3809, Val loss: 0.3351
# Epoch: 224, Train loss: 0.4213, Val loss: 0.2901
# Epoch: 226, Train loss: 0.3745, Val loss: 0.2880
# Epoch: 228, Train loss: 0.3571, Val loss: 0.3083
# Epoch: 230, Train loss: 0.3661, Val loss: 0.2864
# Epoch: 232, Train loss: 0.3732, Val loss: 0.2916
# Epoch: 234, Train loss: 0.3687, Val loss: 0.2982
# Epoch: 236, Train loss: 0.3784, Val loss: 0.2847
# Epoch: 238, Train loss: 0.3491, Val loss: 0.2893
# Epoch: 240, Train loss: 0.3769, Val loss: 0.2842
# Epoch: 242, Train loss: 0.3535, Val loss: 0.2952
# Epoch: 244, Train loss: 0.3456, Val loss: 0.2880
# Epoch: 246, Train loss: 0.3989, Val loss: 0.3034
# Epoch: 248, Train loss: 0.3546, Val loss: 0.3065
# Epoch: 250, Train loss: 0.3458, Val loss: 0.2813
# Epoch: 252, Train loss: 0.3524, Val loss: 0.2900
# Epoch: 254, Train loss: 0.4110, Val loss: 0.3146
# Epoch: 256, Train loss: 0.3633, Val loss: 0.2927
# Epoch: 258, Train loss: 0.3573, Val loss: 0.2815
# Epoch: 260, Train loss: 0.3785, Val loss: 0.3803
# Epoch: 262, Train loss: 0.3636, Val loss: 0.2792
# Epoch: 264, Train loss: 0.3605, Val loss: 0.2778
# Epoch: 266, Train loss: 0.3362, Val loss: 0.2858
# Epoch: 268, Train loss: 0.3746, Val loss: 0.3051
# Epoch: 270, Train loss: 0.3539, Val loss: 0.2765
# Epoch: 272, Train loss: 0.3870, Val loss: 0.2799
# Epoch: 274, Train loss: 0.3760, Val loss: 0.2942
# Epoch: 276, Train loss: 0.3518, Val loss: 0.2740
# Epoch: 278, Train loss: 0.3476, Val loss: 0.2749
# Epoch: 280, Train loss: 0.3552, Val loss: 0.2769
# Epoch: 282, Train loss: 0.3852, Val loss: 0.3434
# Epoch: 284, Train loss: 0.3495, Val loss: 0.2858
# Epoch: 286, Train loss: 0.3750, Val loss: 0.2791
# Epoch: 288, Train loss: 0.3561, Val loss: 0.3214
# Epoch: 290, Train loss: 0.4135, Val loss: 0.2970
# Epoch: 292, Train loss: 0.3936, Val loss: 0.3044
# Epoch: 294, Train loss: 0.3662, Val loss: 0.2726
# Epoch: 296, Train loss: 0.3462, Val loss: 0.2771
# Epoch: 298, Train loss: 0.3455, Val loss: 0.2706
# Epoch: 300, Train loss: 0.3508, Val loss: 0.2682
# Epoch: 302, Train loss: 0.3420, Val loss: 0.2803
# Epoch: 304, Train loss: 0.3305, Val loss: 0.2826
# Epoch: 306, Train loss: 0.3363, Val loss: 0.2684
# Epoch: 308, Train loss: 0.3756, Val loss: 0.3063
# Epoch: 310, Train loss: 0.3858, Val loss: 0.2741
# Epoch: 312, Train loss: 0.3637, Val loss: 0.2782
# Epoch: 314, Train loss: 0.3454, Val loss: 0.2785
# Epoch: 316, Train loss: 0.3609, Val loss: 0.2891
# Epoch: 318, Train loss: 0.3351, Val loss: 0.2679
# Epoch: 320, Train loss: 0.3538, Val loss: 0.3214
# Epoch: 322, Train loss: 0.3447, Val loss: 0.2675
# Epoch: 324, Train loss: 0.3289, Val loss: 0.2699
# Epoch: 326, Train loss: 0.3510, Val loss: 0.2630
# Epoch: 328, Train loss: 0.3332, Val loss: 0.2618
# Epoch: 330, Train loss: 0.3681, Val loss: 0.2635
# Epoch: 332, Train loss: 0.3546, Val loss: 0.2729
# Epoch: 334, Train loss: 0.3295, Val loss: 0.2676
# Epoch: 336, Train loss: 0.3523, Val loss: 0.2752
# Epoch: 338, Train loss: 0.3383, Val loss: 0.2754
# Epoch: 340, Train loss: 0.3330, Val loss: 0.2918
# Epoch: 342, Train loss: 0.3452, Val loss: 0.2621
# Epoch: 344, Train loss: 0.3366, Val loss: 0.2644
# Epoch: 346, Train loss: 0.3399, Val loss: 0.2616
# Epoch: 348, Train loss: 0.3648, Val loss: 0.2694
# Epoch: 350, Train loss: 0.3571, Val loss: 0.2606
# Epoch: 352, Train loss: 0.3443, Val loss: 0.2753
# Epoch: 354, Train loss: 0.3511, Val loss: 0.2832
# Epoch: 356, Train loss: 0.3323, Val loss: 0.2618
# Epoch: 358, Train loss: 0.3574, Val loss: 0.3001
# Epoch: 360, Train loss: 0.3524, Val loss: 0.3331
# Epoch: 362, Train loss: 0.3452, Val loss: 0.2674
# Epoch: 364, Train loss: 0.3597, Val loss: 0.2798
# Epoch: 366, Train loss: 0.3267, Val loss: 0.2635
# Epoch: 368, Train loss: 0.3379, Val loss: 0.2600
# Epoch: 370, Train loss: 0.3364, Val loss: 0.2629
# Epoch: 372, Train loss: 0.3356, Val loss: 0.2745
# Epoch: 374, Train loss: 0.3377, Val loss: 0.2815
# Epoch: 376, Train loss: 0.3128, Val loss: 0.2586
# Epoch: 378, Train loss: 0.3164, Val loss: 0.2639
# Epoch: 380, Train loss: 0.3299, Val loss: 0.2567
# Epoch: 382, Train loss: 0.3237, Val loss: 0.2887
# Epoch: 384, Train loss: 0.3539, Val loss: 0.2610
# Epoch: 386, Train loss: 0.3255, Val loss: 0.2725
# Epoch: 388, Train loss: 0.3252, Val loss: 0.2732
# Epoch: 390, Train loss: 0.3213, Val loss: 0.2613
# Epoch: 392, Train loss: 0.3380, Val loss: 0.2552
# Epoch: 394, Train loss: 0.3399, Val loss: 0.3151
# Epoch: 396, Train loss: 0.3364, Val loss: 0.2619
# Epoch: 398, Train loss: 0.3249, Val loss: 0.2579
# Epoch: 400, Train loss: 0.3394, Val loss: 0.2639
# Epoch: 402, Train loss: 0.3440, Val loss: 0.2535
# Epoch: 404, Train loss: 0.3215, Val loss: 0.2638
# Epoch: 406, Train loss: 0.3514, Val loss: 0.2694
# Epoch: 408, Train loss: 0.3157, Val loss: 0.2510
# Epoch: 410, Train loss: 0.3187, Val loss: 0.2634
# Epoch: 412, Train loss: 0.3352, Val loss: 0.2519
# Epoch: 414, Train loss: 0.3318, Val loss: 0.2550
# Epoch: 416, Train loss: 0.3472, Val loss: 0.2619
# Epoch: 418, Train loss: 0.3658, Val loss: 0.3258
# Epoch: 420, Train loss: 0.3235, Val loss: 0.3166
# Epoch: 422, Train loss: 0.3561, Val loss: 0.2686
# Epoch: 424, Train loss: 0.3411, Val loss: 0.2715
# Epoch: 426, Train loss: 0.3593, Val loss: 0.2783
# Epoch: 428, Train loss: 0.3257, Val loss: 0.2785
# Epoch: 430, Train loss: 0.3222, Val loss: 0.2825
# Epoch: 432, Train loss: 0.3357, Val loss: 0.2618
# Epoch: 434, Train loss: 0.3305, Val loss: 0.2714
# Epoch: 436, Train loss: 0.3275, Val loss: 0.2519
# Epoch: 438, Train loss: 0.3469, Val loss: 0.3316
# Epoch: 440, Train loss: 0.3249, Val loss: 0.2804
# Epoch: 442, Train loss: 0.3306, Val loss: 0.2570
# Epoch: 444, Train loss: 0.3226, Val loss: 0.2617
# Epoch: 446, Train loss: 0.3177, Val loss: 0.2544
# Epoch: 448, Train loss: 0.3298, Val loss: 0.2578
# Epoch: 450, Train loss: 0.3118, Val loss: 0.2847
# Epoch: 452, Train loss: 0.3274, Val loss: 0.2532
# Epoch: 454, Train loss: 0.3269, Val loss: 0.2532
# Epoch: 456, Train loss: 0.3336, Val loss: 0.2581
# Epoch: 458, Train loss: 0.3364, Val loss: 0.2537
# Epoch: 460, Train loss: 0.3338, Val loss: 0.2642
# Epoch: 462, Train loss: 0.3361, Val loss: 0.2860
# Epoch: 464, Train loss: 0.3277, Val loss: 0.2528
# Epoch: 466, Train loss: 0.3261, Val loss: 0.2530
# Epoch: 468, Train loss: 0.3036, Val loss: 0.2591
# Epoch: 470, Train loss: 0.3279, Val loss: 0.2484
# Epoch: 472, Train loss: 0.3180, Val loss: 0.2510
# Epoch: 474, Train loss: 0.3355, Val loss: 0.2661
# Epoch: 476, Train loss: 0.2965, Val loss: 0.2379
# Epoch: 478, Train loss: 0.3093, Val loss: 0.2300
# Epoch: 480, Train loss: 0.3104, Val loss: 0.2257
# Epoch: 482, Train loss: 0.3084, Val loss: 0.2372
# Epoch: 484, Train loss: 0.3443, Val loss: 0.2700
# Epoch: 486, Train loss: 0.3092, Val loss: 0.2439
# Epoch: 488, Train loss: 0.3210, Val loss: 0.2236
# Epoch: 490, Train loss: 0.3182, Val loss: 0.2276
# Epoch: 492, Train loss: 0.2899, Val loss: 0.2166
# Epoch: 494, Train loss: 0.3060, Val loss: 0.2142
# Epoch: 496, Train loss: 0.2914, Val loss: 0.2061
# Epoch: 498, Train loss: 0.3102, Val loss: 0.2608
# Validation MSE: 0.2210, MAE: 0.3518

# %%
plot_loss(anion_gat_train_loss_50, anion_gat_val_loss_50)

# %%
plot_loss(cation_gat_train_loss_50, cation_gat_val_loss_50)

# %%
plot_targets(anion_gat_val_pred_50, anion_gat_val_true_50, anion_gat_mse_50, anion_gat_mae_50, save_path="anion_GAT_val_50.png")

# %%
plot_targets(cation_gat_val_pred_50, cation_gat_val_true_50, cation_gat_mse_50, cation_gat_mae_50, save_path="cation_GAT_val_50.png")

# %% [markdown]
# # 75% train dataset

# %%
# Load the anion training set
anion_75_load_train_dataset_path = 'dataset/train_anion_data_list_75.pt' # Training set
anion_75_loaded_train_data_list = load_data_list(anion_75_load_train_dataset_path)
anion_75_train_loader = DataLoader(anion_75_loaded_train_data_list, batch_size=128, shuffle=True)  

# Load the cation training set
cation_75_load_train_dataset_path = 'dataset/train_cation_data_list_75.pt' # Training set
cation_75_loaded_train_data_list = load_data_list(cation_75_load_train_dataset_path)
cation_75_train_loader = DataLoader(cation_75_loaded_train_data_list, batch_size=128, shuffle=True)

# %%
# Train the GCN model with the number of epochs set to 100
epochs = 500

# Initialize the GCN model with hidden layer dimension set to 256
model_anion_75 = GAT(in_channels=5, hidden_channels=256).to(device)
model_cation_75 = GAT(in_channels=5, hidden_channels=256).to(device)

# %%
anion_gat_train_loss_75, anion_gat_val_loss_75, anion_gat_train_pred_75, anion_gat_train_true_75, anion_gat_val_pred_75, anion_gat_val_true_75, anion_gat_mse_75, anion_gat_mae_75 = train_epochs(
    11, epochs,model_anion_75, anion_75_train_loader, anion_val_loader, "Anion_GAT_model_HOMO_75.pt"
)
# Out:
# Epoch: 0, Train loss: 2.0912, Val loss: 0.9244
# Epoch: 2, Train loss: 1.0874, Val loss: 0.8174
# Epoch: 4, Train loss: 0.9476, Val loss: 0.7317
# Epoch: 6, Train loss: 0.8573, Val loss: 0.7437
# Epoch: 8, Train loss: 0.8387, Val loss: 0.7072
# Epoch: 10, Train loss: 0.8199, Val loss: 0.6865
# Epoch: 12, Train loss: 0.7884, Val loss: 0.6864
# Epoch: 14, Train loss: 0.8507, Val loss: 0.7224
# Epoch: 16, Train loss: 0.8651, Val loss: 0.6696
# Epoch: 18, Train loss: 0.7918, Val loss: 0.7387
# Epoch: 20, Train loss: 0.8321, Val loss: 0.6558
# Epoch: 22, Train loss: 0.7838, Val loss: 0.6928
# Epoch: 24, Train loss: 0.7817, Val loss: 0.6511
# Epoch: 26, Train loss: 0.7590, Val loss: 0.6483
# Epoch: 28, Train loss: 0.7481, Val loss: 0.6299
# Epoch: 30, Train loss: 0.7705, Val loss: 0.6302
# Epoch: 32, Train loss: 0.7403, Val loss: 0.6510
# Epoch: 34, Train loss: 0.7508, Val loss: 0.6158
# Epoch: 36, Train loss: 0.7353, Val loss: 0.6029
# Epoch: 38, Train loss: 0.7258, Val loss: 0.6123
# Epoch: 40, Train loss: 0.7474, Val loss: 0.6058
# Epoch: 42, Train loss: 0.7100, Val loss: 0.5881
# Epoch: 44, Train loss: 0.6855, Val loss: 0.6074
# Epoch: 46, Train loss: 0.6707, Val loss: 0.5661
# Epoch: 48, Train loss: 0.6679, Val loss: 0.5601
# Epoch: 50, Train loss: 0.6436, Val loss: 0.5494
# Epoch: 52, Train loss: 0.6788, Val loss: 0.5380
# Epoch: 54, Train loss: 0.6679, Val loss: 0.6487
# Epoch: 56, Train loss: 0.6331, Val loss: 0.5393
# Epoch: 58, Train loss: 0.6374, Val loss: 0.5761
# Epoch: 60, Train loss: 0.6737, Val loss: 0.5764
# Epoch: 62, Train loss: 0.6353, Val loss: 0.5392
# Epoch: 64, Train loss: 0.6178, Val loss: 0.5290
# Epoch: 66, Train loss: 0.6448, Val loss: 0.5254
# Epoch: 68, Train loss: 0.6121, Val loss: 0.5283
# Epoch: 70, Train loss: 0.6271, Val loss: 0.5305
# Epoch: 72, Train loss: 0.6395, Val loss: 0.5279
# Epoch: 74, Train loss: 0.6197, Val loss: 0.6052
# Epoch: 76, Train loss: 0.6232, Val loss: 0.5150
# Epoch: 78, Train loss: 0.6075, Val loss: 0.5338
# Epoch: 80, Train loss: 0.5900, Val loss: 0.5427
# Epoch: 82, Train loss: 0.6894, Val loss: 0.5574
# Epoch: 84, Train loss: 0.6429, Val loss: 0.5342
# Epoch: 86, Train loss: 0.6229, Val loss: 0.5400
# Epoch: 88, Train loss: 0.6103, Val loss: 0.5606
# Epoch: 90, Train loss: 0.5888, Val loss: 0.5319
# Epoch: 92, Train loss: 0.5909, Val loss: 0.5412
# Epoch: 94, Train loss: 0.6353, Val loss: 0.5064
# Epoch: 96, Train loss: 0.5872, Val loss: 0.5095
# Epoch: 98, Train loss: 0.5823, Val loss: 0.5158
# Epoch: 100, Train loss: 0.5775, Val loss: 0.4972
# Epoch: 102, Train loss: 0.5564, Val loss: 0.5418
# Epoch: 104, Train loss: 0.5761, Val loss: 0.5379
# Epoch: 106, Train loss: 0.6222, Val loss: 0.5734
# Epoch: 108, Train loss: 0.6283, Val loss: 0.5408
# Epoch: 110, Train loss: 0.5641, Val loss: 0.5878
# Epoch: 112, Train loss: 0.5669, Val loss: 0.5176
# Epoch: 114, Train loss: 0.5644, Val loss: 0.5343
# Epoch: 116, Train loss: 0.5750, Val loss: 0.6016
# Epoch: 118, Train loss: 0.6041, Val loss: 0.4893
# Epoch: 120, Train loss: 0.5766, Val loss: 0.5187
# Epoch: 122, Train loss: 0.5412, Val loss: 0.4821
# Epoch: 124, Train loss: 0.5227, Val loss: 0.4955
# Epoch: 126, Train loss: 0.5408, Val loss: 0.5036
# Epoch: 128, Train loss: 0.5528, Val loss: 0.4760
# Epoch: 130, Train loss: 0.5227, Val loss: 0.4654
# Epoch: 132, Train loss: 0.5080, Val loss: 0.5087
# Epoch: 134, Train loss: 0.5169, Val loss: 0.4574
# Epoch: 136, Train loss: 0.5230, Val loss: 0.4405
# Epoch: 138, Train loss: 0.5172, Val loss: 0.4541
# Epoch: 140, Train loss: 0.4981, Val loss: 0.4931
# Epoch: 142, Train loss: 0.4998, Val loss: 0.4274
# Epoch: 144, Train loss: 0.4939, Val loss: 0.4248
# Epoch: 146, Train loss: 0.4714, Val loss: 0.5306
# Epoch: 148, Train loss: 0.4803, Val loss: 0.4199
# Epoch: 150, Train loss: 0.4637, Val loss: 0.4161
# Epoch: 152, Train loss: 0.4609, Val loss: 0.4472
# Epoch: 154, Train loss: 0.5089, Val loss: 0.4227
# Epoch: 156, Train loss: 0.4577, Val loss: 0.3937
# Epoch: 158, Train loss: 0.4439, Val loss: 0.4153
# Epoch: 160, Train loss: 0.4262, Val loss: 0.4030
# Epoch: 162, Train loss: 0.4810, Val loss: 0.4401
# Epoch: 164, Train loss: 0.4227, Val loss: 0.3893
# Epoch: 166, Train loss: 0.4444, Val loss: 0.3833
# Epoch: 168, Train loss: 0.4211, Val loss: 0.3969
# Epoch: 170, Train loss: 0.4193, Val loss: 0.4258
# Epoch: 172, Train loss: 0.4392, Val loss: 0.4204
# Epoch: 174, Train loss: 0.4387, Val loss: 0.4102
# Epoch: 176, Train loss: 0.4117, Val loss: 0.3899
# Epoch: 178, Train loss: 0.4083, Val loss: 0.3862
# Epoch: 180, Train loss: 0.4170, Val loss: 0.4074
# Epoch: 182, Train loss: 0.4113, Val loss: 0.3841
# Epoch: 184, Train loss: 0.3946, Val loss: 0.3770
# Epoch: 186, Train loss: 0.3839, Val loss: 0.3983
# Epoch: 188, Train loss: 0.3795, Val loss: 0.3800
# Epoch: 190, Train loss: 0.3775, Val loss: 0.3881
# Epoch: 192, Train loss: 0.3975, Val loss: 0.3592
# Epoch: 194, Train loss: 0.3594, Val loss: 0.3437
# Epoch: 196, Train loss: 0.3493, Val loss: 0.3564
# Epoch: 198, Train loss: 0.3696, Val loss: 0.3598
# Epoch: 200, Train loss: 0.3532, Val loss: 0.3496
# Epoch: 202, Train loss: 0.3523, Val loss: 0.3840
# Epoch: 204, Train loss: 0.3361, Val loss: 0.3343
# Epoch: 206, Train loss: 0.3333, Val loss: 0.3453
# Epoch: 208, Train loss: 0.3298, Val loss: 0.3338
# Epoch: 210, Train loss: 0.3261, Val loss: 0.3492
# Epoch: 212, Train loss: 0.3283, Val loss: 0.3545
# Epoch: 214, Train loss: 0.3549, Val loss: 0.3502
# Epoch: 216, Train loss: 0.3285, Val loss: 0.3242
# Epoch: 218, Train loss: 0.3198, Val loss: 0.3285
# Epoch: 220, Train loss: 0.3249, Val loss: 0.3185
# Epoch: 222, Train loss: 0.3226, Val loss: 0.3201
# Epoch: 224, Train loss: 0.3282, Val loss: 0.3461
# Epoch: 226, Train loss: 0.3011, Val loss: 0.3287
# Epoch: 228, Train loss: 0.3129, Val loss: 0.3616
# Epoch: 230, Train loss: 0.3322, Val loss: 0.3451
# Epoch: 232, Train loss: 0.2969, Val loss: 0.3064
# Epoch: 234, Train loss: 0.3148, Val loss: 0.3065
# Epoch: 236, Train loss: 0.3198, Val loss: 0.3028
# Epoch: 238, Train loss: 0.3023, Val loss: 0.3099
# Epoch: 240, Train loss: 0.2908, Val loss: 0.2970
# Epoch: 242, Train loss: 0.2732, Val loss: 0.2989
# Epoch: 244, Train loss: 0.3201, Val loss: 0.2958
# Epoch: 246, Train loss: 0.3026, Val loss: 0.2910
# Epoch: 248, Train loss: 0.2859, Val loss: 0.3174
# Epoch: 250, Train loss: 0.3070, Val loss: 0.3053
# Epoch: 252, Train loss: 0.2857, Val loss: 0.2888
# Epoch: 254, Train loss: 0.2848, Val loss: 0.3058
# Epoch: 256, Train loss: 0.2692, Val loss: 0.2901
# Epoch: 258, Train loss: 0.2793, Val loss: 0.2795
# Epoch: 260, Train loss: 0.2740, Val loss: 0.2887
# Epoch: 262, Train loss: 0.2609, Val loss: 0.2822
# Epoch: 264, Train loss: 0.2592, Val loss: 0.2893
# Epoch: 266, Train loss: 0.2902, Val loss: 0.2723
# Epoch: 268, Train loss: 0.2591, Val loss: 0.2969
# Epoch: 270, Train loss: 0.2810, Val loss: 0.2803
# Epoch: 272, Train loss: 0.2569, Val loss: 0.2774
# Epoch: 274, Train loss: 0.2466, Val loss: 0.2712
# Epoch: 276, Train loss: 0.2655, Val loss: 0.2672
# Epoch: 278, Train loss: 0.2456, Val loss: 0.2692
# Epoch: 280, Train loss: 0.2728, Val loss: 0.2951
# Epoch: 282, Train loss: 0.2521, Val loss: 0.2595
# Epoch: 284, Train loss: 0.2384, Val loss: 0.2561
# Epoch: 286, Train loss: 0.2383, Val loss: 0.2681
# Epoch: 288, Train loss: 0.2394, Val loss: 0.2577
# Epoch: 290, Train loss: 0.2692, Val loss: 0.3421
# Epoch: 292, Train loss: 0.2586, Val loss: 0.2734
# Epoch: 294, Train loss: 0.2440, Val loss: 0.2631
# Epoch: 296, Train loss: 0.2475, Val loss: 0.2913
# Epoch: 298, Train loss: 0.2474, Val loss: 0.2477
# Epoch: 300, Train loss: 0.2336, Val loss: 0.2459
# Epoch: 302, Train loss: 0.2301, Val loss: 0.2500
# Epoch: 304, Train loss: 0.2378, Val loss: 0.2529
# Epoch: 306, Train loss: 0.2657, Val loss: 0.2641
# Epoch: 308, Train loss: 0.2615, Val loss: 0.3084
# Epoch: 310, Train loss: 0.2588, Val loss: 0.2568
# Epoch: 312, Train loss: 0.2382, Val loss: 0.2530
# Epoch: 314, Train loss: 0.2255, Val loss: 0.2490
# Epoch: 316, Train loss: 0.2533, Val loss: 0.2396
# Epoch: 318, Train loss: 0.2476, Val loss: 0.2557
# Epoch: 320, Train loss: 0.2267, Val loss: 0.2399
# Epoch: 322, Train loss: 0.2253, Val loss: 0.2462
# Epoch: 324, Train loss: 0.2490, Val loss: 0.3325
# Epoch: 326, Train loss: 0.2449, Val loss: 0.2435
# Epoch: 328, Train loss: 0.2328, Val loss: 0.2566
# Epoch: 330, Train loss: 0.2503, Val loss: 0.2621
# Epoch: 332, Train loss: 0.2351, Val loss: 0.2969
# Epoch: 334, Train loss: 0.2222, Val loss: 0.2412
# Epoch: 336, Train loss: 0.2159, Val loss: 0.2445
# Epoch: 338, Train loss: 0.2175, Val loss: 0.2556
# Epoch: 340, Train loss: 0.2376, Val loss: 0.2646
# Epoch: 342, Train loss: 0.2293, Val loss: 0.2466
# Epoch: 344, Train loss: 0.2558, Val loss: 0.2327
# Epoch: 346, Train loss: 0.2821, Val loss: 0.2280
# Epoch: 348, Train loss: 0.2427, Val loss: 0.2426
# Epoch: 350, Train loss: 0.2397, Val loss: 0.2554
# Epoch: 352, Train loss: 0.2202, Val loss: 0.2474
# Epoch: 354, Train loss: 0.2295, Val loss: 0.2645
# Epoch: 356, Train loss: 0.2034, Val loss: 0.2353
# Epoch: 358, Train loss: 0.2042, Val loss: 0.2294
# Epoch: 360, Train loss: 0.2192, Val loss: 0.2665
# Epoch: 362, Train loss: 0.2282, Val loss: 0.2342
# Epoch: 364, Train loss: 0.2091, Val loss: 0.2414
# Epoch: 366, Train loss: 0.2465, Val loss: 0.2184
# Epoch: 368, Train loss: 0.2000, Val loss: 0.2124
# Epoch: 370, Train loss: 0.1924, Val loss: 0.2190
# Epoch: 372, Train loss: 0.1887, Val loss: 0.2278
# Epoch: 374, Train loss: 0.2073, Val loss: 0.2470
# Epoch: 376, Train loss: 0.1876, Val loss: 0.2263
# Epoch: 378, Train loss: 0.1912, Val loss: 0.2528
# Epoch: 380, Train loss: 0.2103, Val loss: 0.2035
# Epoch: 382, Train loss: 0.1974, Val loss: 0.2143
# Epoch: 384, Train loss: 0.2150, Val loss: 0.2651
# Epoch: 386, Train loss: 0.2040, Val loss: 0.2200
# Epoch: 388, Train loss: 0.1949, Val loss: 0.2132
# Epoch: 390, Train loss: 0.2033, Val loss: 0.2342
# Epoch: 392, Train loss: 0.1988, Val loss: 0.2116
# Epoch: 394, Train loss: 0.1811, Val loss: 0.2025
# Epoch: 396, Train loss: 0.2016, Val loss: 0.2162
# Epoch: 398, Train loss: 0.1877, Val loss: 0.1976
# Epoch: 400, Train loss: 0.2013, Val loss: 0.2009
# Epoch: 402, Train loss: 0.2090, Val loss: 0.2088
# Epoch: 404, Train loss: 0.1861, Val loss: 0.2261
# Epoch: 406, Train loss: 0.1884, Val loss: 0.2057
# Epoch: 408, Train loss: 0.2138, Val loss: 0.2253
# Epoch: 410, Train loss: 0.1829, Val loss: 0.1936
# Epoch: 412, Train loss: 0.2121, Val loss: 0.2404
# Epoch: 414, Train loss: 0.1816, Val loss: 0.2020
# Epoch: 416, Train loss: 0.1755, Val loss: 0.2093
# Epoch: 418, Train loss: 0.1965, Val loss: 0.2169
# Epoch: 420, Train loss: 0.1882, Val loss: 0.1960
# Epoch: 422, Train loss: 0.1862, Val loss: 0.1916
# Epoch: 424, Train loss: 0.1734, Val loss: 0.2435
# Epoch: 426, Train loss: 0.1777, Val loss: 0.2334
# Epoch: 428, Train loss: 0.1954, Val loss: 0.2246
# Epoch: 430, Train loss: 0.1598, Val loss: 0.1835
# Epoch: 432, Train loss: 0.1971, Val loss: 0.2018
# Epoch: 434, Train loss: 0.1961, Val loss: 0.2016
# Epoch: 436, Train loss: 0.1993, Val loss: 0.2128
# Epoch: 438, Train loss: 0.1784, Val loss: 0.1874
# Epoch: 440, Train loss: 0.1748, Val loss: 0.2208
# Epoch: 442, Train loss: 0.1650, Val loss: 0.2109
# Epoch: 444, Train loss: 0.1783, Val loss: 0.1888
# Epoch: 446, Train loss: 0.1660, Val loss: 0.2152
# Epoch: 448, Train loss: 0.1756, Val loss: 0.2529
# Epoch: 450, Train loss: 0.1848, Val loss: 0.1952
# Epoch: 452, Train loss: 0.1702, Val loss: 0.1896
# Epoch: 454, Train loss: 0.1702, Val loss: 0.2056
# Epoch: 456, Train loss: 0.1802, Val loss: 0.1913
# Epoch: 458, Train loss: 0.1978, Val loss: 0.2099
# Epoch: 460, Train loss: 0.1816, Val loss: 0.1979
# Epoch: 462, Train loss: 0.1753, Val loss: 0.2156
# Epoch: 464, Train loss: 0.1616, Val loss: 0.1983
# Epoch: 466, Train loss: 0.1646, Val loss: 0.1899
# Epoch: 468, Train loss: 0.1796, Val loss: 0.1794
# Epoch: 470, Train loss: 0.1643, Val loss: 0.1901
# Epoch: 472, Train loss: 0.1666, Val loss: 0.1996
# Epoch: 474, Train loss: 0.1684, Val loss: 0.1888
# Epoch: 476, Train loss: 0.1855, Val loss: 0.1966
# Epoch: 478, Train loss: 0.1676, Val loss: 0.1889
# Epoch: 480, Train loss: 0.1697, Val loss: 0.1816
# Epoch: 482, Train loss: 0.1788, Val loss: 0.2100
# Epoch: 484, Train loss: 0.1662, Val loss: 0.1912
# Epoch: 486, Train loss: 0.1767, Val loss: 0.2111
# Epoch: 488, Train loss: 0.2006, Val loss: 0.2283
# Epoch: 490, Train loss: 0.1639, Val loss: 0.1851
# Epoch: 492, Train loss: 0.1816, Val loss: 0.1892
# Epoch: 494, Train loss: 0.1972, Val loss: 0.2082
# Epoch: 496, Train loss: 0.1891, Val loss: 0.2239
# Epoch: 498, Train loss: 0.1781, Val loss: 0.1976
# Validation MSE: 0.1962, MAE: 0.3374

# %%
cation_gat_train_loss_75, cation_gat_val_loss_75, cation_gat_train_pred_75, cation_gat_train_true_75, cation_gat_val_pred_75, cation_gat_val_true_75, cation_gat_mse_75, cation_gat_mae_75 = train_epochs(
    12, epochs,model_cation_75, cation_75_train_loader, cation_val_loader, "Cation_GAT_model_LUMO_75.pt"
)
# Out:
# Epoch: 0, Train loss: 4.0817, Val loss: 1.9510
# Epoch: 2, Train loss: 1.4541, Val loss: 1.1640
# Epoch: 4, Train loss: 0.9487, Val loss: 0.7624
# Epoch: 6, Train loss: 0.8272, Val loss: 0.6647
# Epoch: 8, Train loss: 0.7605, Val loss: 0.6786
# Epoch: 10, Train loss: 0.8017, Val loss: 0.7408
# Epoch: 12, Train loss: 0.7403, Val loss: 0.5920
# Epoch: 14, Train loss: 0.7493, Val loss: 0.5865
# Epoch: 16, Train loss: 0.7650, Val loss: 0.6305
# Epoch: 18, Train loss: 0.6638, Val loss: 0.5352
# Epoch: 20, Train loss: 0.6297, Val loss: 0.5083
# Epoch: 22, Train loss: 0.6688, Val loss: 0.5522
# Epoch: 24, Train loss: 0.6144, Val loss: 0.4757
# Epoch: 26, Train loss: 0.6056, Val loss: 0.5567
# Epoch: 28, Train loss: 0.5793, Val loss: 0.4963
# Epoch: 30, Train loss: 0.5813, Val loss: 0.4338
# Epoch: 32, Train loss: 0.5902, Val loss: 0.4359
# Epoch: 34, Train loss: 0.5608, Val loss: 0.4017
# Epoch: 36, Train loss: 0.5908, Val loss: 0.4483
# Epoch: 38, Train loss: 0.5538, Val loss: 0.4517
# Epoch: 40, Train loss: 0.5186, Val loss: 0.3698
# Epoch: 42, Train loss: 0.4929, Val loss: 0.3658
# Epoch: 44, Train loss: 0.5093, Val loss: 0.4201
# Epoch: 46, Train loss: 0.4871, Val loss: 0.3583
# Epoch: 48, Train loss: 0.4734, Val loss: 0.3654
# Epoch: 50, Train loss: 0.5081, Val loss: 0.4214
# Epoch: 52, Train loss: 0.4816, Val loss: 0.3542
# Epoch: 54, Train loss: 0.4669, Val loss: 0.3518
# Epoch: 56, Train loss: 0.4786, Val loss: 0.3448
# Epoch: 58, Train loss: 0.4745, Val loss: 0.3551
# Epoch: 60, Train loss: 0.4906, Val loss: 0.3992
# Epoch: 62, Train loss: 0.4855, Val loss: 0.4164
# Epoch: 64, Train loss: 0.4769, Val loss: 0.3875
# Epoch: 66, Train loss: 0.4541, Val loss: 0.3357
# Epoch: 68, Train loss: 0.4465, Val loss: 0.3503
# Epoch: 70, Train loss: 0.4539, Val loss: 0.3304
# Epoch: 72, Train loss: 0.4477, Val loss: 0.3259
# Epoch: 74, Train loss: 0.4494, Val loss: 0.3646
# Epoch: 76, Train loss: 0.4721, Val loss: 0.3267
# Epoch: 78, Train loss: 0.4458, Val loss: 0.3280
# Epoch: 80, Train loss: 0.4366, Val loss: 0.3277
# Epoch: 82, Train loss: 0.4524, Val loss: 0.3154
# Epoch: 84, Train loss: 0.4695, Val loss: 0.3265
# Epoch: 86, Train loss: 0.4363, Val loss: 0.3258
# Epoch: 88, Train loss: 0.4400, Val loss: 0.3146
# Epoch: 90, Train loss: 0.4185, Val loss: 0.3069
# Epoch: 92, Train loss: 0.4464, Val loss: 0.3490
# Epoch: 94, Train loss: 0.4112, Val loss: 0.3035
# Epoch: 96, Train loss: 0.4408, Val loss: 0.3098
# Epoch: 98, Train loss: 0.4240, Val loss: 0.2995
# Epoch: 100, Train loss: 0.4006, Val loss: 0.3046
# Epoch: 102, Train loss: 0.4257, Val loss: 0.3189
# Epoch: 104, Train loss: 0.4366, Val loss: 0.2928
# Epoch: 106, Train loss: 0.3925, Val loss: 0.2817
# Epoch: 108, Train loss: 0.4515, Val loss: 0.2851
# Epoch: 110, Train loss: 0.3787, Val loss: 0.2709
# Epoch: 112, Train loss: 0.3839, Val loss: 0.2813
# Epoch: 114, Train loss: 0.3806, Val loss: 0.3484
# Epoch: 116, Train loss: 0.3675, Val loss: 0.2609
# Epoch: 118, Train loss: 0.3797, Val loss: 0.2664
# Epoch: 120, Train loss: 0.3954, Val loss: 0.2482
# Epoch: 122, Train loss: 0.3699, Val loss: 0.2432
# Epoch: 124, Train loss: 0.3418, Val loss: 0.2460
# Epoch: 126, Train loss: 0.3495, Val loss: 0.2912
# Epoch: 128, Train loss: 0.3759, Val loss: 0.2550
# Epoch: 130, Train loss: 0.3580, Val loss: 0.2539
# Epoch: 132, Train loss: 0.3408, Val loss: 0.2351
# Epoch: 134, Train loss: 0.3391, Val loss: 0.2578
# Epoch: 136, Train loss: 0.3397, Val loss: 0.2324
# Epoch: 138, Train loss: 0.3422, Val loss: 0.2176
# Epoch: 140, Train loss: 0.3393, Val loss: 0.2257
# Epoch: 142, Train loss: 0.3278, Val loss: 0.2207
# Epoch: 144, Train loss: 0.3203, Val loss: 0.2429
# Epoch: 146, Train loss: 0.3170, Val loss: 0.2241
# Epoch: 148, Train loss: 0.3397, Val loss: 0.2438
# Epoch: 150, Train loss: 0.3325, Val loss: 0.2835
# Epoch: 152, Train loss: 0.3452, Val loss: 0.2237
# Epoch: 154, Train loss: 0.3203, Val loss: 0.2243
# Epoch: 156, Train loss: 0.3105, Val loss: 0.2059
# Epoch: 158, Train loss: 0.3181, Val loss: 0.2110
# Epoch: 160, Train loss: 0.2979, Val loss: 0.2263
# Epoch: 162, Train loss: 0.3032, Val loss: 0.2107
# Epoch: 164, Train loss: 0.3164, Val loss: 0.2271
# Epoch: 166, Train loss: 0.3483, Val loss: 0.2049
# Epoch: 168, Train loss: 0.3159, Val loss: 0.2060
# Epoch: 170, Train loss: 0.3002, Val loss: 0.2053
# Epoch: 172, Train loss: 0.2971, Val loss: 0.1924
# Epoch: 174, Train loss: 0.3119, Val loss: 0.2550
# Epoch: 176, Train loss: 0.3030, Val loss: 0.2145
# Epoch: 178, Train loss: 0.3025, Val loss: 0.2091
# Epoch: 180, Train loss: 0.2956, Val loss: 0.2132
# Epoch: 182, Train loss: 0.2853, Val loss: 0.1894
# Epoch: 184, Train loss: 0.2906, Val loss: 0.1974
# Epoch: 186, Train loss: 0.2960, Val loss: 0.1835
# Epoch: 188, Train loss: 0.3026, Val loss: 0.1958
# Epoch: 190, Train loss: 0.2971, Val loss: 0.1901
# Epoch: 192, Train loss: 0.2871, Val loss: 0.1823
# Epoch: 194, Train loss: 0.2967, Val loss: 0.1899
# Epoch: 196, Train loss: 0.2853, Val loss: 0.1929
# Epoch: 198, Train loss: 0.3110, Val loss: 0.1931
# Epoch: 200, Train loss: 0.3160, Val loss: 0.1970
# Epoch: 202, Train loss: 0.2929, Val loss: 0.1873
# Epoch: 204, Train loss: 0.3009, Val loss: 0.2085
# Epoch: 206, Train loss: 0.2801, Val loss: 0.1930
# Epoch: 208, Train loss: 0.3030, Val loss: 0.1818
# Epoch: 210, Train loss: 0.2745, Val loss: 0.1991
# Epoch: 212, Train loss: 0.2961, Val loss: 0.1842
# Epoch: 214, Train loss: 0.2790, Val loss: 0.2179
# Epoch: 216, Train loss: 0.2979, Val loss: 0.1862
# Epoch: 218, Train loss: 0.2786, Val loss: 0.1779
# Epoch: 220, Train loss: 0.2926, Val loss: 0.1757
# Epoch: 222, Train loss: 0.2716, Val loss: 0.2250
# Epoch: 224, Train loss: 0.2991, Val loss: 0.1811
# Epoch: 226, Train loss: 0.2829, Val loss: 0.1872
# Epoch: 228, Train loss: 0.2707, Val loss: 0.1733
# Epoch: 230, Train loss: 0.3203, Val loss: 0.1976
# Epoch: 232, Train loss: 0.2709, Val loss: 0.1775
# Epoch: 234, Train loss: 0.2654, Val loss: 0.1980
# Epoch: 236, Train loss: 0.2664, Val loss: 0.2074
# Epoch: 238, Train loss: 0.2552, Val loss: 0.1812
# Epoch: 240, Train loss: 0.2753, Val loss: 0.1924
# Epoch: 242, Train loss: 0.2674, Val loss: 0.1802
# Epoch: 244, Train loss: 0.2868, Val loss: 0.1856
# Epoch: 246, Train loss: 0.2590, Val loss: 0.1978
# Epoch: 248, Train loss: 0.2752, Val loss: 0.1720
# Epoch: 250, Train loss: 0.2688, Val loss: 0.1976
# Epoch: 252, Train loss: 0.2683, Val loss: 0.1745
# Epoch: 254, Train loss: 0.2894, Val loss: 0.2030
# Epoch: 256, Train loss: 0.2621, Val loss: 0.1707
# Epoch: 258, Train loss: 0.2537, Val loss: 0.2069
# Epoch: 260, Train loss: 0.2591, Val loss: 0.1655
# Epoch: 262, Train loss: 0.2820, Val loss: 0.1725
# Epoch: 264, Train loss: 0.2650, Val loss: 0.1700
# Epoch: 266, Train loss: 0.2612, Val loss: 0.1981
# Epoch: 268, Train loss: 0.2706, Val loss: 0.1660
# Epoch: 270, Train loss: 0.2712, Val loss: 0.1612
# Epoch: 272, Train loss: 0.2524, Val loss: 0.1616
# Epoch: 274, Train loss: 0.2686, Val loss: 0.1713
# Epoch: 276, Train loss: 0.2743, Val loss: 0.1688
# Epoch: 278, Train loss: 0.2655, Val loss: 0.1619
# Epoch: 280, Train loss: 0.2578, Val loss: 0.1608
# Epoch: 282, Train loss: 0.2480, Val loss: 0.1764
# Epoch: 284, Train loss: 0.2885, Val loss: 0.1700
# Epoch: 286, Train loss: 0.2756, Val loss: 0.1625
# Epoch: 288, Train loss: 0.2648, Val loss: 0.1777
# Epoch: 290, Train loss: 0.2714, Val loss: 0.1643
# Epoch: 292, Train loss: 0.2740, Val loss: 0.2272
# Epoch: 294, Train loss: 0.2550, Val loss: 0.1856
# Epoch: 296, Train loss: 0.2541, Val loss: 0.1796
# Epoch: 298, Train loss: 0.2785, Val loss: 0.1620
# Epoch: 300, Train loss: 0.2796, Val loss: 0.1739
# Epoch: 302, Train loss: 0.2343, Val loss: 0.1692
# Epoch: 304, Train loss: 0.2574, Val loss: 0.1668
# Epoch: 306, Train loss: 0.2564, Val loss: 0.1613
# Epoch: 308, Train loss: 0.2545, Val loss: 0.1633
# Epoch: 310, Train loss: 0.2560, Val loss: 0.1876
# Epoch: 312, Train loss: 0.2712, Val loss: 0.1923
# Epoch: 314, Train loss: 0.2595, Val loss: 0.1652
# Epoch: 316, Train loss: 0.2475, Val loss: 0.1674
# Epoch: 318, Train loss: 0.2669, Val loss: 0.1579
# Epoch: 320, Train loss: 0.2529, Val loss: 0.1706
# Epoch: 322, Train loss: 0.2562, Val loss: 0.1720
# Epoch: 324, Train loss: 0.2726, Val loss: 0.2040
# Epoch: 326, Train loss: 0.2419, Val loss: 0.1619
# Epoch: 328, Train loss: 0.2401, Val loss: 0.1699
# Epoch: 330, Train loss: 0.2452, Val loss: 0.1804
# Epoch: 332, Train loss: 0.2830, Val loss: 0.2189
# Epoch: 334, Train loss: 0.2553, Val loss: 0.1693
# Epoch: 336, Train loss: 0.2711, Val loss: 0.2421
# Epoch: 338, Train loss: 0.2392, Val loss: 0.1672
# Epoch: 340, Train loss: 0.2365, Val loss: 0.1649
# Epoch: 342, Train loss: 0.2569, Val loss: 0.1813
# Epoch: 344, Train loss: 0.2545, Val loss: 0.1916
# Epoch: 346, Train loss: 0.2590, Val loss: 0.1587
# Epoch: 348, Train loss: 0.2448, Val loss: 0.1683
# Epoch: 350, Train loss: 0.2366, Val loss: 0.1569
# Epoch: 352, Train loss: 0.2564, Val loss: 0.1746
# Epoch: 354, Train loss: 0.2416, Val loss: 0.1722
# Epoch: 356, Train loss: 0.2492, Val loss: 0.1516
# Epoch: 358, Train loss: 0.2483, Val loss: 0.2133
# Epoch: 360, Train loss: 0.2547, Val loss: 0.1683
# Epoch: 362, Train loss: 0.2588, Val loss: 0.1572
# Epoch: 364, Train loss: 0.2594, Val loss: 0.1625
# Epoch: 366, Train loss: 0.2442, Val loss: 0.1602
# Epoch: 368, Train loss: 0.2505, Val loss: 0.1713
# Epoch: 370, Train loss: 0.2470, Val loss: 0.1599
# Epoch: 372, Train loss: 0.2276, Val loss: 0.1619
# Epoch: 374, Train loss: 0.2411, Val loss: 0.1795
# Epoch: 376, Train loss: 0.2522, Val loss: 0.1660
# Epoch: 378, Train loss: 0.2480, Val loss: 0.1558
# Epoch: 380, Train loss: 0.2453, Val loss: 0.1653
# Epoch: 382, Train loss: 0.2320, Val loss: 0.1836
# Epoch: 384, Train loss: 0.2695, Val loss: 0.1671
# Epoch: 386, Train loss: 0.2436, Val loss: 0.1962
# Epoch: 388, Train loss: 0.2315, Val loss: 0.1515
# Epoch: 390, Train loss: 0.2471, Val loss: 0.1913
# Epoch: 392, Train loss: 0.2747, Val loss: 0.1710
# Epoch: 394, Train loss: 0.2358, Val loss: 0.2052
# Epoch: 396, Train loss: 0.2289, Val loss: 0.1611
# Epoch: 398, Train loss: 0.2519, Val loss: 0.1919
# Epoch: 400, Train loss: 0.2489, Val loss: 0.2062
# Epoch: 402, Train loss: 0.2298, Val loss: 0.1552
# Epoch: 404, Train loss: 0.2388, Val loss: 0.1983
# Epoch: 406, Train loss: 0.2432, Val loss: 0.1909
# Epoch: 408, Train loss: 0.2358, Val loss: 0.2114
# Epoch: 410, Train loss: 0.2418, Val loss: 0.1706
# Epoch: 412, Train loss: 0.2345, Val loss: 0.1613
# Epoch: 414, Train loss: 0.2426, Val loss: 0.1565
# Epoch: 416, Train loss: 0.2536, Val loss: 0.1569
# Epoch: 418, Train loss: 0.2351, Val loss: 0.1506
# Epoch: 420, Train loss: 0.2232, Val loss: 0.1598
# Epoch: 422, Train loss: 0.2383, Val loss: 0.1532
# Epoch: 424, Train loss: 0.2185, Val loss: 0.1707
# Epoch: 426, Train loss: 0.2350, Val loss: 0.1596
# Epoch: 428, Train loss: 0.2249, Val loss: 0.1659
# Epoch: 430, Train loss: 0.2730, Val loss: 0.1680
# Epoch: 432, Train loss: 0.2414, Val loss: 0.1547
# Epoch: 434, Train loss: 0.2621, Val loss: 0.1800
# Epoch: 436, Train loss: 0.2572, Val loss: 0.1708
# Epoch: 438, Train loss: 0.2411, Val loss: 0.1655
# Epoch: 440, Train loss: 0.2305, Val loss: 0.1466
# Epoch: 442, Train loss: 0.2314, Val loss: 0.1763
# Epoch: 444, Train loss: 0.2387, Val loss: 0.1576
# Epoch: 446, Train loss: 0.2282, Val loss: 0.1603
# Epoch: 448, Train loss: 0.2299, Val loss: 0.1699
# Epoch: 450, Train loss: 0.2552, Val loss: 0.1769
# Epoch: 452, Train loss: 0.2362, Val loss: 0.1485
# Epoch: 454, Train loss: 0.2577, Val loss: 0.1610
# Epoch: 456, Train loss: 0.2367, Val loss: 0.1642
# Epoch: 458, Train loss: 0.2431, Val loss: 0.1577
# Epoch: 460, Train loss: 0.2564, Val loss: 0.1715
# Epoch: 462, Train loss: 0.2335, Val loss: 0.1530
# Epoch: 464, Train loss: 0.2254, Val loss: 0.1660
# Epoch: 466, Train loss: 0.2368, Val loss: 0.1676
# Epoch: 468, Train loss: 0.2507, Val loss: 0.1958
# Epoch: 470, Train loss: 0.2299, Val loss: 0.1601
# Epoch: 472, Train loss: 0.2278, Val loss: 0.1772
# Epoch: 474, Train loss: 0.2268, Val loss: 0.1572
# Epoch: 476, Train loss: 0.2217, Val loss: 0.1732
# Epoch: 478, Train loss: 0.2315, Val loss: 0.1641
# Epoch: 480, Train loss: 0.2204, Val loss: 0.1509
# Epoch: 482, Train loss: 0.2300, Val loss: 0.1518
# Epoch: 484, Train loss: 0.2209, Val loss: 0.1460
# Epoch: 486, Train loss: 0.2308, Val loss: 0.1527
# Epoch: 488, Train loss: 0.2578, Val loss: 0.1564
# Epoch: 490, Train loss: 0.2400, Val loss: 0.1518
# Epoch: 492, Train loss: 0.2373, Val loss: 0.1505
# Epoch: 494, Train loss: 0.2326, Val loss: 0.1525
# Epoch: 496, Train loss: 0.2222, Val loss: 0.1507
# Epoch: 498, Train loss: 0.2335, Val loss: 0.1591
# Validation MSE: 0.1701, MAE: 0.3080

# %%
plot_loss(anion_gat_train_loss_75, anion_gat_val_loss_75)

# %%
plot_loss(cation_gat_train_loss_75, cation_gat_val_loss_75)

# %%
plot_targets(anion_gat_val_pred_75, anion_gat_val_true_75, anion_gat_mse_75, anion_gat_mae_75, save_path="anion_GAT_val_75.png")

# %%
plot_targets(cation_gat_val_pred_75, cation_gat_val_true_75, cation_gat_mse_75, cation_gat_mae_75, save_path="cation_GAT_val_75.png")
